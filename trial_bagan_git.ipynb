# %% [markdown]
# <a href="https://colab.research.google.com/github/abbyambita/Diagnosing-COVID-from-CT-Scan-Images/blob/main/trial_bagan_git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/seokinj/BAGAN/

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os 

os.chdir("/content/gdrive/My Drive")

#!ls  '/content/gdrive/My Drive/CS 284 Mini-Project/Code/'

# %cd "/content/gdrive/My Drive/CS 284 Mini-Project/Code/"
# Out:
# /content/gdrive/.shortcut-targets-by-id/1eVFVz23F6ROX0s10Oe3tT9HVzr502iW2/CS 284 Mini-Project/Code

# %%
from __future__ import print_function
#%matplotlib inline
import argparse
import os
import PIL
import glob
import xml.etree.ElementTree as ET
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import seaborn as sns
from IPython.display import HTML
from torchvision.utils import save_image
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau, CosineAnnealingLR
from tqdm import tqdm_notebook as tqdm
from IPython.display import clear_output
from scipy.stats import truncnorm
# %matplotlib inline
plt.rcParams['image.interpolation'] = 'nearest'

from easydict import EasyDict as edict
from PIL import Image
from collections import OrderedDict
import yaml
import imageio
import numpy as np
import torch.utils.data as data
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import sys
import time
import math

import scipy.misc
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.autograd import Variable

# %%
workers = 6
display= 10
epoches= 100
test_epoches= 30
batch_size= 32
base_lr= 0.0002
beta1= 0.5
ano_para= 0.1
image_size= 64 
z_dim= 100
c_dim= 3
gf_dim= 64
df_dim= 64
#class_num= 10
class_num= 2
pretrained = True

dir = "epochs="+str(epoches)+"_lr="+str(base_lr)+"_batch_size="+str(batch_size)
checkpoint_dir = "model_backup/bagan/git/"+dir
save_dir = "plots/bagan/git/"+dir
distribution_dir ="model_result/bagan/git/"+dir+"/distribution"
output_images_dir = "bagan_output_images/git/"+dir

os.makedirs("model_result/bagan/git/"+dir, exist_ok=True)
os.makedirs("plots/bagan/git/"+dir, exist_ok=True)
os.makedirs("model_backup/bagan/git/"+dir, exist_ok=True)
os.makedirs(output_images_dir, exist_ok=True)


os.makedirs("model_result/bagan/git/"+dir+"/distribution", exist_ok=True)

os.makedirs(save_dir+"/accuracy", exist_ok=True)
os.makedirs(save_dir+"/loss", exist_ok=True)
os.makedirs(checkpoint_dir+"/gan", exist_ok=True)
os.makedirs(checkpoint_dir+"/vae", exist_ok=True)

# %%
def load_images(batch_size, image_size):
  dataroot = "revised-git/train"

  dataset = dset.ImageFolder(root=dataroot,
                            transform=transforms.Compose([
                                transforms.Resize(image_size),
                                transforms.RandomHorizontalFlip(),
                                transforms.CenterCrop(image_size),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                            ]))
  
  
  dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,shuffle=True, num_workers=workers)

  return dataloader

# %%
dataloader = load_images(32, 128)
print(len(dataloader))
# real_batch = iter(dataloader).next()
# plt.figure(figsize=(15,15))
# plt.axis("off")
# plt.title("Training Images")
# image = np.transpose(vutils.make_grid(real_batch[0].to(device), normalize=True).cpu(),axes=(1,2,0))
# plt.imshow(image)
# Out:
# 14

# %%
import torch
import torch.nn as nn

# Generator
class Decoder(nn.Module):
	def __init__(self, z_dim, c_dim, gf_dim):
		super(Decoder, self).__init__()

		self.convTrans0 = nn.ConvTranspose2d(z_dim, gf_dim*8, 4, 1, 0, bias=False)
		self.bn0 = nn.BatchNorm2d(gf_dim*8)
		self.relu0 = nn.ReLU(inplace=True)
		
		self.convTrans1 = nn.ConvTranspose2d(gf_dim*8, gf_dim*4, 4, 2, 1, bias=False)
		self.bn1 = nn.BatchNorm2d(gf_dim*4)
		self.relu1 = nn.ReLU(inplace=True)

		self.convTrans2 = nn.ConvTranspose2d(gf_dim*4, gf_dim*2, 4, 2, 1, bias=False)
		self.bn2 = nn.BatchNorm2d(gf_dim*2)
		self.relu2 = nn.ReLU(inplace=True)

		self.convTrans3 = nn.ConvTranspose2d(gf_dim*2, gf_dim, 4, 2, 1, bias=False)
		self.bn3 = nn.BatchNorm2d(gf_dim)
		self.relu3 = nn.ReLU(inplace=True)

		self.convTrans4 = nn.ConvTranspose2d(gf_dim, c_dim, 4, 2, 1, bias=False)
		self.tanh = nn.Tanh()

		for m in self.modules():
				if isinstance(m, nn.ConvTranspose2d):
						m.weight.data.normal_(0.0, 0.02)
						if m.bias is not None:
								m.bias.data.zero_()

	def forward(self, z):
		h0 = self.relu0(self.bn0(self.convTrans0(z)))
		h1 = self.relu1(self.bn1(self.convTrans1(h0)))
		h2 = self.relu2(self.bn2(self.convTrans2(h1)))
		h3 = self.relu3(self.bn3(self.convTrans3(h2)))
		h4 = self.convTrans4(h3)
		output = self.tanh(h4)
		return output # (c_dim, 64, 64)

# Discriminator
class Encoder(nn.Module): 
	def __init__(self, z_dim, c_dim, df_dim):
		super(Encoder, self).__init__()
		self.df_dim = df_dim

		self.conv0 = nn.Conv2d(c_dim, df_dim, 4, 2, 1, bias=False)
		self.relu0 = nn.LeakyReLU(0.2, inplace=True)
		
		self.conv1 = nn.Conv2d(df_dim, df_dim*2, 4, 2, 1, bias=False)
		self.bn1 = nn.BatchNorm2d(df_dim*2)
		self.relu1 = nn.LeakyReLU(0.2, inplace=True)

		self.conv2 = nn.Conv2d(df_dim*2, df_dim*4, 4, 2, 1, bias=False)
		self.bn2 = nn.BatchNorm2d(df_dim*4)
		self.relu2 = nn.LeakyReLU(0.2, inplace=True)

		self.conv3 = nn.Conv2d(df_dim*4, df_dim*8, 4, 2, 1, bias=False)
		self.bn3 = nn.BatchNorm2d(df_dim*8)
		self.relu3 = nn.LeakyReLU(0.2, inplace=True)

		self.fc_z1 = nn.Linear(df_dim*8*4*4, z_dim)
		self.fc_z2 = nn.Linear(df_dim*8*4*4, z_dim)

		#self.conv4 = nn.Conv2d(df_dim*8, 1, 4, 1, 0, bias=False)

		for m in self.modules():
				if isinstance(m, nn.Conv2d):
						m.weight.data.normal_(0.0, 0.02)
						if m.bias is not None:
								m.bias.data.zero_()

	def forward(self, input):
		h0 = self.relu0(self.conv0(input))
		h1 = self.relu1(self.bn1(self.conv1(h0)))
		h2 = self.relu2(self.bn2(self.conv2(h1)))
		h3 = self.relu3(self.bn3(self.conv3(h2)))
		
		mu = self.fc_z1(h3.view(-1, self.df_dim*8*4*4))	# (1, 128*8*4*4)
		sigma = self.fc_z2(h3.view(-1, self.df_dim*8*4*4))
		return mu,sigma # by squeeze, get just float not float Tenosor


class Generator(nn.Module):
        def __init__(self, z_dim, c_dim, gf_dim):
                super(Generator, self).__init__()

                self.convTrans0 = nn.ConvTranspose2d(z_dim, gf_dim*8, 4, 1, 0, bias=False)
                self.bn0 = nn.BatchNorm2d(gf_dim*8)
                self.relu0 = nn.ReLU(inplace=True)

                self.convTrans1 = nn.ConvTranspose2d(gf_dim*8, gf_dim*4, 4, 2, 1, bias=False)
                self.bn1 = nn.BatchNorm2d(gf_dim*4)
                self.relu1 = nn.ReLU(inplace=True)

                self.convTrans2 = nn.ConvTranspose2d(gf_dim*4, gf_dim*2, 4, 2, 1, bias=False)
                self.bn2 = nn.BatchNorm2d(gf_dim*2)
                self.relu2 = nn.ReLU(inplace=True)

                self.convTrans3 = nn.ConvTranspose2d(gf_dim*2, gf_dim, 4, 2, 1, bias=False)
                self.bn3 = nn.BatchNorm2d(gf_dim)
                self.relu3 = nn.ReLU(inplace=True)

                self.convTrans4 = nn.ConvTranspose2d(gf_dim, c_dim, 4, 2, 1, bias=False)
                self.tanh = nn.Tanh()


        def forward(self, z):
                h0 = self.relu0(self.bn0(self.convTrans0(z)))
                h1 = self.relu1(self.bn1(self.convTrans1(h0)))
                h2 = self.relu2(self.bn2(self.convTrans2(h1)))
                h3 = self.relu3(self.bn3(self.convTrans3(h2)))
                h4 = self.convTrans4(h3)
                output = self.tanh(h4)
                return output # (c_dim, 64, 64)

class _ganLogits(nn.Module):
    '''
    Layer of the GAN logits of the discriminator
    The layer gets class logits as inputs and calculates GAN logits to
    differentiate real and fake images in a numerical stable way
    '''
    def __init__(self, num_classes):
        '''
        :param num_classes: Number of real data classes (10 for SVHN)
        '''
        super(_ganLogits, self).__init__()
        self.num_classes = num_classes

    def forward(self, class_logits):
        '''
        :param class_logits: Unscaled log probabilities of house numbers
        '''

        # Set gan_logits such that P(input is real | input) = sigmoid(gan_logits).
        # Keep in mind that class_logits gives you the probability distribution over all the real
        # classes and the fake class. You need to work out how to transform this multiclass softmax
        # distribution into a binary real-vs-fake decision that can be described with a sigmoid.
        # Numerical stability is very important.
        # You'll probably need to use this numerical stability trick:
        # log sum_i exp a_i = m + log sum_i exp(a_i - m).
        # This is numerically stable when m = max_i a_i.
        # (It helps to think about what goes wrong when...
        #   1. One value of a_i is very large
        #   2. All the values of a_i are very negative
        # This trick and this value of m fix both those cases, but the naive implementation and
        # other values of m encounter various problems)
        real_class_logits, fake_class_logits = torch.split(class_logits, self.num_classes, dim=1)
        fake_class_logits = torch.squeeze(fake_class_logits)

        max_val, _ = torch.max(real_class_logits, 1, keepdim=True)
        stable_class_logits = real_class_logits - max_val
        max_val = torch.squeeze(max_val)
        gan_logits = torch.log(torch.sum(torch.exp(stable_class_logits), 1)) + max_val - fake_class_logits

        return gan_logits	# [128]

class Discriminator(nn.Module):
        def __init__(self, z_dim, c_dim, df_dim, class_num):
                super(Discriminator, self).__init__()
                self.df_dim = df_dim

                self.conv0 = nn.Conv2d(c_dim, df_dim, 4, 2, 1, bias=False)
                self.relu0 = nn.LeakyReLU(0.2, inplace=True)

                self.conv1 = nn.Conv2d(df_dim, df_dim*2, 4, 2, 1, bias=False)
                self.bn1 = nn.BatchNorm2d(df_dim*2)
                self.relu1 = nn.LeakyReLU(0.2, inplace=True)

                self.conv2 = nn.Conv2d(df_dim*2, df_dim*4, 4, 2, 1, bias=False)
                self.bn2 = nn.BatchNorm2d(df_dim*4)
                self.relu2 = nn.LeakyReLU(0.2, inplace=True)

                self.conv3 = nn.Conv2d(df_dim*4, df_dim*8, 4, 2, 1, bias=False)
                self.bn3 = nn.BatchNorm2d(df_dim*8)
                self.relu3 = nn.LeakyReLU(0.2, inplace=True)

		#self.fc_z = nn.Linear(df_dim*8*4*4, z_dim)
                self.fc_aux = nn.Linear(df_dim*8*4*4, class_num+1)
                self.softmax = nn.LogSoftmax()

                for m in self.modules():
                        if isinstance(m, nn.Linear):
                                m.weight.data.normal_(0.0, 0.02)
                                if m.bias is not None:
                                        m.bias.data.zero_()


        def forward(self, input):
                h0 = self.relu0(self.conv0(input))
                h1 = self.relu1(self.bn1(self.conv1(h0)))
                h2 = self.relu2(self.bn2(self.conv2(h1)))
                h3 = self.relu3(self.bn3(self.conv3(h2)))
                #cl = self.class_logistics(h3.view(-1, self.df_dim*8*4*4))
                #gl = self.gan_logistics(cl)    
                output = self.softmax(self.fc_aux(h3.view(-1, self.df_dim*8*4*4)))
                return h3, output
                #return h3, output.view(-1,1).squeeze(1) # by squeeze, get just float not float Tenosor

# %%
def conditional_latent_generator(distribution, class_num, batch):
	class_labels = torch.randint(0, class_num, (batch,), dtype=torch.long)
	fake_z = distribution[class_labels[0].item()].sample((1,))
	for c in class_labels[1:]:
		fake_z = torch.cat((fake_z, distribution[c.item()].sample((1,))), dim=0)
	return fake_z, class_labels

# %%
def batch2one(Z, y, z, class_num):
	for i in range(y.shape[0]):
		Z[y[i]] = torch.cat((Z[y[i]], z[i].cpu()), dim=0) # Z[label][0] should be deleted..
	return Z			
	
class AverageMeter(object):
    """ Computes ans stores the average and current value"""
    def __init__(self):
        self.reset()
    
    def reset(self):
        self.val = 0.
        self.avg = 0.
        self.sum = 0.
        self.count = 0
    
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def one_hot(x, num_classes):
        '''
        One-hot encoding of the vector of classes. It uses number of classes + 1 to
        encode fake images
        :param x: vector of output classes to one-hot encode
        :return: one-hot encoded version of the input vector
        '''
        label_numpy = x.data.cpu().numpy()
        label_onehot = np.zeros((label_numpy.shape[0], num_classes + 1))
        label_onehot[np.arange(label_numpy.shape[0]), label_numpy] = 1
        return torch.FloatTensor(label_onehot)


def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
                m.weight.data.normal_(0.0, 0.02)
        elif classname.find('BatchNorm') != -1:
                m.weight.data.normal_(1.0, 0.02)
                m.bias.data.fill_(0)

# %%
def save_checkpoint(state, filename='checkpoint'):
    torch.save(state, filename + '.pth.tar')

def print_gan_log(epoch, epoches, iteration, iters, learning_rate,
              display, batch_time, data_time, D_losses, G_losses):
    print('epoch: [{}/{}] iteration: [{}/{}]\t'
          'Learning rate: {}'.format(epoch, epoches, iteration, iters, learning_rate))
    print('Time {batch_time.sum:.3f}s / {0}iters, ({batch_time.avg:.3f})\t'
          'Data load {data_time.sum:.3f}s / {0}iters, ({data_time.avg:3f})\n'
          'Loss_D = {loss_D.val:.8f} (ave = {loss_D.avg:.8f})\n'
          'Loss_G = {loss_G.val:.8f} (ave = {loss_G.avg:.8f})\n'.format(
              display, batch_time=batch_time,
              data_time=data_time, loss_D=D_losses, loss_G=G_losses))

# %%
#Clear
def print_vae_log(epoch, epoches, iteration, iters, learning_rate,
              display, batch_time, data_time, losses):

    print('epoch: [{}/{}] iteration: [{}/{}]\t'
          'Learning rate: {}'.format(epoch, epoches, iteration, iters, learning_rate))
    print('Time {batch_time.sum:.3f}s / {0}iters, ({batch_time.avg:.3f})\t'
          'Data load {data_time.sum:.3f}s / {0}iters, ({data_time.avg:3f})\n'
          'Loss = {loss.val:.8f} (ave = {loss.avg:.8f})\n'.format(
              display, batch_time=batch_time,
              data_time=data_time, loss=losses))

# %%
def plot_result2(fake, image_size, num_epoch, save_dir, name, fig_size=(8, 8), is_gray=False):

    generate_images = fake
    #G.train() # for next train after plot_result at a epoch ...

    n_rows = n_cols = 8
    fig, axes = plt.subplots(n_rows, n_cols, figsize=fig_size)

    for ax, img in zip(axes.flatten(), generate_images):
        ax.axis('off')
        ax.set_adjustable('box')
        if is_gray:
            img = img.cpu().data.view(image_size, image_size).numpy()
            ax.imshow(img, cmap='gray', aspect='equal')
        else:
            img = (((img - img.min()) * 255) / (img.max() - img.min())).cpu().data.numpy().transpose(1, 2, 0).astype(np.uint8)
            ax.imshow(img, cmap=None, aspect='equal')
    plt.subplots_adjust(wspace=0, hspace=0)
    title = 'Epoch {0}'.format(num_epoch)
    fig.text(0.5, 0.04, title, ha='center')

    if name == "dcgan":
        plt.savefig(os.path.join(save_dir, 'DCGAN_epoch_{}.png'.format(num_epoch)))
        plt.close()

    elif name == "anomaly":
        plt.savefig(os.path.join(save_dir, 'anoGAN_epoch_{}.png'.format(num_epoch)))
        plt.close()

    elif name == "vae":
        plt.savefig(os.path.join(save_dir, 'vae_epoch_{}.png'.format(num_epoch)))
        plt.close()

    elif name =="gan":
        plt.savefig(os.path.join(save_dir, 'gan_epoch_{}.png'.format(num_epoch)))
        plt.close()

def plot_result(G, fixed_noise, image_size, num_epoch, save_dir, name, fig_size=(8, 8), is_gray=False):

    G.eval()
    generate_images = G(fixed_noise)
    G.train() # for next train after plot_result at a epoch ... 
    
    n_rows = n_cols = 8
    fig, axes = plt.subplots(n_rows, n_cols, figsize=fig_size)
    
    for ax, img in zip(axes.flatten(), generate_images):
        ax.axis('off')
        ax.set_adjustable('box')
        if is_gray:
            img = img.cpu().data.view(image_size, image_size).numpy()
            ax.imshow(img, cmap='gray', aspect='equal')
        else:
            img = (((img - img.min()) * 255) / (img.max() - img.min())).cpu().data.numpy().transpose(1, 2, 0).astype(np.uint8)
            ax.imshow(img, cmap=None, aspect='equal')
    plt.subplots_adjust(wspace=0, hspace=0)
    title = 'Epoch {0}'.format(num_epoch)
    fig.text(0.5, 0.04, title, ha='center')
    
    if name == "dcgan":
        plt.savefig(os.path.join(save_dir, 'DCGAN_epoch_{}.png'.format(num_epoch)))
        plt.close()

    elif name == "anomaly":
        plt.savefig(os.path.join(save_dir, 'anoGAN_epoch_{}.png'.format(num_epoch)))
        plt.close()

    elif name == "vae":
        plt.savefig(os.path.join(save_dir, 'vae_epoch_{}.png'.format(num_epoch)))
        plt.close()
    
    elif name =="gan":
        plt.savefig(os.path.join(save_dir, 'gan_epoch_{}.png'.format(num_epoch)))
        plt.close()

#Clear    
def plot_loss(num_epoch, epoches, save_dir, **loss):
    fig, ax = plt.subplots() 
    ax.set_xlim(0,epoches + 1)
    if len(loss) == 2:
        ax.set_ylim(0, max(np.max(loss['g_loss']), np.max(loss['d_loss'])) * 1.1)
    elif len(loss) == 1:
        ax.set_ylim(0, max(np.max(loss['vae_loss'])) * 1.1)
    plt.xlabel('Epoch {}'.format(num_epoch))
    plt.ylabel('Loss')
    
    if len(loss) == 2:
        plt.plot([i for i in range(1, num_epoch + 1)], loss['d_loss'], label='Discriminator', color='red', linewidth=3)
        plt.plot([i for i in range(1, num_epoch + 1)], loss['g_loss'], label='Generator', color='mediumblue', linewidth=3)
        plt.legend()
        plt.savefig(os.path.join(os.path.join(save_dir, "loss"), 'gan_loss_epoch_{}.png'.format(num_epoch)))
    elif len(loss) == 1:
        plt.plot([i for i in range(1, num_epoch + 1)], loss['vae_loss'], label='vae_loss', color='red', linewidht=3)
        plt.legend()
        plt.savefig(os.path.join(os.path.join(save_dir, "loss"), 'vae_loss_epoch_{}.png'.format(num_epoch)))
 
    plt.close()

#Clear
def plot_accuracy(num_epoch, epoches, save_dir, real_acc, fake_acc):
	fig, ax = plt.subplots()
	ax.set_xlim(0,epoches + 1)
	ax.set_ylim(0, max(np.max(real_acc), np.max(fake_acc)) * 1.1)
	plt.xlabel('Epoch {}'.format(num_epoch))
	plt.ylabel('Accuracy')

	plt.plot([i for i in range(1, num_epoch + 1)], real_acc, label='real data', color='red', linewidth=3)
	plt.plot([i for i in range(1, num_epoch + 1)], fake_acc, label='fake data', color='mediumblue', linewidth=3)
	plt.legend()
	plt.savefig(os.path.join(os.path.join(save_dir, "accuracy"), 'gan_accuracy_epoch_{}.png'.format(num_epoch)))

	plt.close()

# %%
import torch.distributions.multivariate_normal as mn

# %%
#run as pretrained = False first then run again with pretrained = True??? Baket?
pretrained = False
if __name__ == "__main__":
  use_cuda = torch.cuda.is_available()
  gpu = 0

  train_loader = load_images(batch_size, image_size)


  decoder = Decoder(z_dim, c_dim, gf_dim)
  encoder = Encoder(z_dim, c_dim, df_dim)

  if not pretrained:
    if use_cuda:
      decoder = decoder.cuda(gpu)
      encoder = encoder.cuda(gpu)

    # WHY BECLoss() - only need to determine fake/real for Discriminator
    criterion = nn.BCELoss()
    if use_cuda:
      criterion = criterion.cuda(gpu)

    optimizerE = torch.optim.Adam(encoder.parameters(), lr=base_lr, betas=(beta1, 0.999))
    optimizerD = torch.optim.Adam(decoder.parameters(), lr=base_lr, betas=(beta1, 0.999))

    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()

    fixed_noise = torch.FloatTensor(8 * 8, z_dim, 1, 1).normal_(0, 1)
    if use_cuda:
      fixed_noise = fixed_noise.cuda(gpu)
    with torch.no_grad():
      fixed_noisev = fixed_noise

    end = time.time()
    
    encoder.train()
    decoder.train()
    loss_list = []

    
    criterion = nn.MSELoss(size_average=False)	
    for epoch in range(epoches):
      for i, (input, label) in enumerate(train_loader):
        #l Update 'D' : max log(D(x)) + log(1-D(G(z)))
        data_time.update(time.time()-end)
      
        batch_size = input.size(0)
        if use_cuda:
          input = input.cuda(gpu)
        
        mu, log_sigmoid = encoder(input)
        # reparameterization
        std = torch.exp(log_sigmoid/2)
        eps = torch.randn_like(std)
        z = mu + eps * std
        z = z.view(-1, z_dim, 1, 1)	
        if use_cuda:
          z = z.cuda(gpu)

        # reconstruct image
        x_reconstruct = decoder(z)

        # reconstruct_loss + KL_divergence
        reconstruct_loss = criterion(x_reconstruct, input)
        kl_div = -0.5 * torch.sum(1+log_sigmoid-mu.pow(2)-log_sigmoid.exp())
        loss = reconstruct_loss + kl_div
        losses.update(loss.item())	
        optimizerE.zero_grad()
        optimizerD.zero_grad()
        loss.backward()
        optimizerE.step()
        optimizerD.step()

        batch_time.update(time.time()-end)
        end = time.time()
    
        # log every 100th train data of train_loader - display(100)	
        if (i+1) % display == 0:
          print_vae_log(epoch+1, epoches, i+1, len(train_loader), base_lr, display, batch_time, data_time, losses)
          # Is it Continous ???
          batch_time.reset()
          data_time.reset()
        # log every 1 epoch (all of train_loader)
        elif (i+1) == len(train_loader):
          print_vae_log(epoch + 1, epoches, i + 1, len(train_loader), base_lr, (i + 1) % display, batch_time, data_time, losses)
          batch_time.reset()
          data_time.reset()

      # log every 1 epoch
      loss_list.append(losses.avg)
      losses.reset()

      plot_result(decoder, fixed_noisev, image_size, epoch + 1,save_dir, 'vae', is_gray=(c_dim == 1))
      #plot_loss(epoch+1, config.epoches, args.save_dir, vae_loss=loss_list)
      # save the D and G.
      save_checkpoint({'epoch': epoch, 'state_dict': encoder.state_dict(),}, os.path.join(os.path.join(checkpoint_dir,"vae"), 'encoder_epoch_{}'.format(epoch)))
      save_checkpoint({'epoch': epoch, 'state_dict': decoder.state_dict(),}, os.path.join(os.path.join(checkpoint_dir,"vae"), 'decoder_epoch_{}'.format(epoch)))

    #create_gif(epoches, save_dir, 'vae')

  ## Class Conditional Generator - Pretrained Model"
  else:
    print("Class Conditional Generator - Use Pretrained Model")
    if use_cuda:
      encoder = encoder.cuda(gpu)
      decoder = decoder.cuda(gpu)
    encoder.load_state_dict(torch.load(os.path.join(os.path.join(checkpoint_dir, "vae"), "encoder_epoch_"+ str(epoches-1) + ".pth.tar"))['state_dict'])
    decoder.load_state_dict(torch.load(os.path.join(os.path.join(checkpoint_dir, "vae"), "decoder_epoch_"+ str(epoches-1) + ".pth.tar"))['state_dict'])
    #Z = np.empty([config.class_num, config.z_dim], dtype=float)
    # Z : [label-1, labe-2, ... ]
    # Z[label-1] : [[z1], [z2], ... ] (#labeld_data, #z_dim)
    encoder.eval()
    decoder.eval()
    Z = []
    with torch.no_grad():
      for i in range(class_num):
        Z.append(torch.zeros((1, z_dim), dtype=torch.float)) # Z : [class_num, z_dim]
    
      for i, (input, label) in enumerate(train_loader):
        if use_cuda:
          input = input.cuda(gpu)
        mu, log_sigmoid = encoder(input)
        std = torch.exp(log_sigmoid/2)
        eps = torch.randn_like(std)
        z = mu + eps * std
        z = z.view(-1, 1, z_dim)
        Z = batch2one(Z, label, z, class_num)

      N = []
      for i in range(class_num):
        label_mean = torch.mean(Z[i][1:], dim=0).float()
        label_cov = torch.from_numpy(np.cov(Z[i][1:].numpy(), rowvar=False)).float()
        #print("{}th Z : {}".format(i+1, Z[i][1:].shape))
        #print("{}-class  mean : {}".format(i+1, label_mean.shape))
        #print("{}-class covariance : {}".format(i+1, label_cov.shape))
        m = mn.MultivariateNormal(label_mean, label_cov)
        sample = m.sample((64,))
        print(sample.shape)
        if use_cuda:
          sample = sample.cuda(gpu)
        fake = decoder(sample.view(-1, z_dim, 1, 1))
        
        
        plot_result2(fake, image_size, i, 'data/gan/samples', 'ssgan', is_gray=(c_dim == 1))
        N.append(m)
      print("uhm")
      torch.save({'distribution': N}, os.path.join(distribution_dir, 'class_distribution')+'.dt')
# Out:
# Class Conditional Generator - Use Pretrained Model
# torch.Size([64, 100])
# torch.Size([64, 100])
# uhm

# %%
pretrained = True
if __name__ == "__main__":
  use_cuda = torch.cuda.is_available()
  gpu = 0

  # parser.add_argument('--save_dir', type=str, dest='save_dir', help='the path of generated data dir', default='sample')
  # parser.add_argument('--distribution_dir', type=str, dest='distribution_dir', help='the path of class distribution dir', default='distribution')
  # parser.add_argument('--test_dir', type=str, dest='test_dir', help='the path of anomaly test data')
  # parser.add_argument('--test_result_dir', type=str, dest='test_result_dir', help='the path of anomaly test result dir')
  train_loader = load_images(batch_size, image_size)

  G = Generator(z_dim, c_dim, gf_dim)
  G.apply(weights_init)

  D = Discriminator(z_dim, c_dim, df_dim, class_num)
  D.apply(weights_init)

  # if not pretrained:
  #   if use_cuda:
  #     print("duh")
  #     G = G.cuda(gpu)
  #     D = D.cuda(gpu)

  if use_cuda:
    print("duh")
    G = G.cuda(gpu)
    D = D.cuda(gpu)


  distribution = torch.load(os.path.join(distribution_dir,'class_distribution.dt'))['distribution']

  #G.load_state_dict(torch.load(os.path.join(os.path.join(args.checkpoint_dir,"vae") , "decoder_epoch_"+str(config.epoches-1) + ".pth.tar"))['state_dict'])

  # state_e = torch.load(os.path.join(os.path.join(args.checkpoint_dir,"vae"), "encoder_epoch_"+str(config.epoches-1) + ".pth.tar"))['state_dict']
  # del state_e['fc_z1.weight']
  # del state_e['fc_z1.bias']
  # del state_e['fc_z2.weight']
  # del state_e['fc_z2.bias']
  # state_e.update({'fc_aux.weight':D.state_dict()['fc_aux.weight']})
  # state_e.update({'fc_aux.bias':D.state_dict()['fc_aux.bias']})

  # D.load_state_dict(state_e)

  criterion = nn.NLLLoss()

  optimizerD = torch.optim.Adam(D.parameters(), lr=base_lr, betas=(beta1, 0.999))
  optimizerG = torch.optim.Adam(G.parameters(), lr=base_lr, betas=(beta1, 0.999))

  batch_time = AverageMeter()
  data_time = AverageMeter()
  D_losses = AverageMeter()
  G_losses = AverageMeter()

  #fixed_noise = torch.FloatTensor(8 * 8, config.z_dim, 1, 1).normal_(0, 1)
  #if use_cuda:
  #	fixed_noise = fixed_noise.cuda(gpu)
  #with torch.no_grad():
  #	fixed_noisev = fixed_noise

  end = time.time()

  D.train()
  G.train()
  D_loss_list = []
  G_loss_list = []

  real_label = torch.LongTensor(batch_size)
  fake_label = torch.LongTensor(batch_size)	

  for epoch in range(epoches):
    total_real = 0
    total_fake = 0
    correct_real = 0
    correct_fake = 0
    for i, (input, label) in enumerate(train_loader):
      # Update 'D' : max log(D(x)) + log(1-D(G(z)))
      data_time.update(time.time()-end)
      batch_size = input.size(0)
      fake_num = math.ceil(batch_size/class_num)	# For each batch, 1/(n+1) of total images are fake
      conditional_z, z_label = conditional_latent_generator(distribution, class_num, batch_size)

      label = label.long().squeeze() # "squeeze" : [batch, 1] --> [batch] ... e.g) [1,2,3,4...]		
      #print(label[0])
      #print(path[0])
      if use_cuda:
        input = input.cuda(gpu)
        label = label.cuda(gpu)

      sample_features, D_real = D(input)
      real_label.resize_(batch_size).copy_(label)	# "cpu" : gpu --> cpu // <<.data.cpu vs cpu>> // "resize_as" : get tensor size and resize 
      if use_cuda:
        real_label = real_label.cuda(gpu) 
      
      D_loss_real = criterion(D_real, real_label)
      noise = conditional_z[0:fake_num].view(-1, z_dim, 1, 1)

      fake_label.resize_(noise.shape[0]).fill_(class_num)	# fake_label = '(num_class)+1'
      if use_cuda:
        noise = noise.cuda(gpu)
        fake_label = fake_label.cuda(gpu)
        z_label = z_label.cuda(gpu)
      
      fake = G(noise)

      _, D_fake = D(fake.detach())	# Fake image...
      D_loss_fake = criterion(D_fake, fake_label)	# Hmmmm...... fake_label? or z_label?

      D_loss = D_loss_real + D_loss_fake
      D_losses.update(D_loss.item())
      D.zero_grad()
      G.zero_grad()
      D_loss.backward()
      optimizerD.step()

      # Update 'G' : max log(D(G(z)))
      noise = conditional_z.view(-1, z_dim, 1, 1)
      if use_cuda:
        noise = noise.cuda(gpu)
      fake = G(noise)
      _, D_fake = D(fake)
      G_loss = criterion(D_fake, z_label)
      #G_losses.update(G_loss.data[0])
      G_losses.update(G_loss.item())

      D.zero_grad()
      G.zero_grad()
      G_loss.backward()
      optimizerG.step()

      batch_time.update(time.time()-end)
      end = time.time()
      
      pred_real = torch.max(D_real.data, 1)[1]
      pred_fake = torch.max(D_fake.data, 1)[1]
      total_real += real_label.size(0)
      total_fake += z_label.size(0)
      correct_real += (pred_real == real_label).sum().item()
      correct_fake += (pred_fake == z_label).sum().item()

      # log every 100th train data of train_loader - display(100)	
      if (i+1) % display == 0:
        print_gan_log(epoch+1, epoches, i+1, len(train_loader), base_lr, display, batch_time, data_time, D_losses, G_losses)
        # Is it Continous ???
        batch_time.reset()
        data_time.reset()
      # log every 1 epoch (all of train_loader) ... "End of all mini-Batch"
      elif (i+1) == len(train_loader):
        print_gan_log(epoch + 1, epoches, i + 1, len(train_loader), base_lr,
                          (i + 1) % display, batch_time, data_time, D_losses, G_losses)
        #accuracy = masked_correct.item()/max(1.0, num_samples.item())
        plot_result2(fake, image_size, epoch + 1, save_dir, 'gan', is_gray=(c_dim == 1))
        real_acc = 100 * correct_real / total_real
        fake_acc = 100 * correct_fake / total_fake
        print('Real Accuracy : {}'.format(real_acc))
        print('Fake Accuracy : {}'.format(fake_acc))
        #plot_accuracy(epoch+1, epoches, save_dir, real_acc, fake_acc)
        batch_time.reset()
        data_time.reset()

    # log every 1 epoch
    D_loss_list.append(D_losses.avg)
    G_loss_list.append(G_losses.avg)
    D_losses.reset()
    G_losses.reset()

    plot_result(G, fixed_noisev, image_size, epoch + 1, save_dir, 'gan', is_gray=(c_dim == 1))
    plot_loss(epoch+1,epoches, save_dir, d_loss=D_loss_list, g_loss=G_loss_list)
    # save the D and G.
    #save_checkpoint({'epoch': epoch, 'state_dict': D.state_dict(),}, os.path.join(os.path.join(checkpoint_dir,'gan'), 'D_epoch_{}'.format(epoch)))
    #save_checkpoint({'epoch': epoch, 'state_dict': G.state_dict(),}, os.path.join(os.path.join(checkpoint_dir,'gan'), 'G_epoch_{}'.format(epoch)))

    torch.save(D, os.path.join(os.path.join(checkpoint_dir,'gan'), 'D_epoch_{}.pth'.format(epoch)))
    torch.save(G, os.path.join(os.path.join(checkpoint_dir,'gan'), 'G_epoch_{}.pth'.format(epoch)))
# Out:
# duh
# tensor(1)
# tensor(1)
# tensor(0)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:198: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Streaming output truncated to the last 5000 lines.
# epoch: [34/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.486s / 10iters, (0.049)	Data load 0.055s / 10iters, (0.005542)
# Loss_D = 0.31990531 (ave = 0.73323233)
# Loss_G = 3.95210099 (ave = 4.65215393)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [34/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.485s / 10iters, (0.048)	Data load 0.054s / 10iters, (0.005444)
# Loss_D = 0.49906525 (ave = 0.67127148)
# Loss_G = 5.40744972 (ave = 4.61496042)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [34/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.451s / 10iters, (0.045)	Data load 0.048s / 10iters, (0.004838)
# Loss_D = 0.23666142 (ave = 0.70361310)
# Loss_G = 4.39089584 (ave = 4.61854378)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [34/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.162s / 8iters, (0.020)	Data load 0.032s / 8iters, (0.003980)
# Loss_D = 0.02309337 (ave = 0.73263838)
# Loss_G = 5.81444407 (ave = 4.68850798)
#
# Real Accuracy : 84.0
# Fake Accuracy : 6.117647058823529
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [35/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.333s / 10iters, (0.533)	Data load 4.728s / 10iters, (0.472787)
# Loss_D = 0.53600800 (ave = 0.78340261)
# Loss_G = 4.79389143 (ave = 4.61482167)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [35/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.495s / 10iters, (0.049)	Data load 0.061s / 10iters, (0.006095)
# Loss_D = 0.47536659 (ave = 0.70219501)
# Loss_G = 3.17466426 (ave = 4.74630806)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [35/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.563s / 10iters, (0.056)	Data load 0.082s / 10iters, (0.008187)
# Loss_D = 0.33047372 (ave = 0.75180645)
# Loss_G = 4.83338690 (ave = 4.76274697)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [35/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.397s / 10iters, (0.040)	Data load 0.077s / 10iters, (0.007738)
# Loss_D = 0.56326425 (ave = 0.74835253)
# Loss_G = 3.28639483 (ave = 4.70516111)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [35/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.164s / 8iters, (0.020)	Data load 0.029s / 8iters, (0.003569)
# Loss_D = 0.09346928 (ave = 0.72311851)
# Loss_G = 8.30728149 (ave = 4.74889109)
#
# Real Accuracy : 83.76470588235294
# Fake Accuracy : 3.5294117647058822
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [36/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.476s / 10iters, (0.548)	Data load 5.004s / 10iters, (0.500359)
# Loss_D = 0.42142302 (ave = 0.65140005)
# Loss_G = 5.10489416 (ave = 4.13539386)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [36/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.495s / 10iters, (0.049)	Data load 0.053s / 10iters, (0.005300)
# Loss_D = 0.99104476 (ave = 0.70422124)
# Loss_G = 5.29091549 (ave = 4.61562209)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [36/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.527s / 10iters, (0.053)	Data load 0.069s / 10iters, (0.006861)
# Loss_D = 0.34790576 (ave = 0.71577701)
# Loss_G = 5.48981142 (ave = 4.73127999)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [36/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.365s / 10iters, (0.036)	Data load 0.059s / 10iters, (0.005930)
# Loss_D = 1.35361731 (ave = 0.69166245)
# Loss_G = 2.19205141 (ave = 4.67161725)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [36/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.159s / 8iters, (0.020)	Data load 0.027s / 8iters, (0.003373)
# Loss_D = 0.18157746 (ave = 0.69355134)
# Loss_G = 3.44038463 (ave = 4.59918041)
#
# Real Accuracy : 83.52941176470588
# Fake Accuracy : 4.235294117647059
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [37/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.650s / 10iters, (0.465)	Data load 4.095s / 10iters, (0.409526)
# Loss_D = 0.18119001 (ave = 0.58488422)
# Loss_G = 4.20210123 (ave = 4.97392154)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [37/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.505s / 10iters, (0.051)	Data load 0.061s / 10iters, (0.006065)
# Loss_D = 0.61375213 (ave = 0.60609417)
# Loss_G = 4.33285999 (ave = 4.79332331)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [37/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.526s / 10iters, (0.053)	Data load 0.054s / 10iters, (0.005426)
# Loss_D = 0.36479759 (ave = 0.59577956)
# Loss_G = 3.02375031 (ave = 4.58977648)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [37/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.491s / 10iters, (0.049)	Data load 0.062s / 10iters, (0.006195)
# Loss_D = 0.22780494 (ave = 0.68633427)
# Loss_G = 3.87229323 (ave = 4.75512918)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [37/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.161s / 8iters, (0.020)	Data load 0.033s / 8iters, (0.004133)
# Loss_D = 0.03328007 (ave = 0.64517407)
# Loss_G = 4.60232925 (ave = 4.75631346)
#
# Real Accuracy : 88.0
# Fake Accuracy : 1.8823529411764706
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [38/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.193s / 10iters, (0.519)	Data load 4.766s / 10iters, (0.476629)
# Loss_D = 0.20178047 (ave = 0.45807408)
# Loss_G = 6.02749205 (ave = 4.48105652)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [38/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.576s / 10iters, (0.058)	Data load 0.066s / 10iters, (0.006595)
# Loss_D = 0.73185223 (ave = 0.50082824)
# Loss_G = 4.49886227 (ave = 4.66327112)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [38/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.491s / 10iters, (0.049)	Data load 0.064s / 10iters, (0.006419)
# Loss_D = 0.42679140 (ave = 0.63371079)
# Loss_G = 5.28892708 (ave = 4.68062852)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [38/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.514s / 10iters, (0.051)	Data load 0.083s / 10iters, (0.008282)
# Loss_D = 1.14012778 (ave = 0.63276945)
# Loss_G = 4.22051096 (ave = 4.72655670)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [38/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.178s / 8iters, (0.022)	Data load 0.033s / 8iters, (0.004140)
# Loss_D = 0.39410657 (ave = 0.59546594)
# Loss_G = 5.74411488 (ave = 4.63673297)
#
# Real Accuracy : 85.6470588235294
# Fake Accuracy : 3.2941176470588234
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [39/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.590s / 10iters, (0.559)	Data load 4.862s / 10iters, (0.486173)
# Loss_D = 0.41892239 (ave = 0.65271212)
# Loss_G = 5.49927855 (ave = 4.71380215)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [39/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.591s / 10iters, (0.059)	Data load 0.066s / 10iters, (0.006632)
# Loss_D = 0.29209185 (ave = 0.54692801)
# Loss_G = 4.02459145 (ave = 4.48433052)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [39/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.566s / 10iters, (0.057)	Data load 0.062s / 10iters, (0.006232)
# Loss_D = 1.67660129 (ave = 0.58161300)
# Loss_G = 1.55365384 (ave = 4.28945314)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [39/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.378s / 10iters, (0.038)	Data load 0.045s / 10iters, (0.004533)
# Loss_D = 0.82644337 (ave = 0.63382458)
# Loss_G = 7.15394354 (ave = 4.54466269)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [39/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.175s / 8iters, (0.022)	Data load 0.037s / 8iters, (0.004647)
# Loss_D = 1.68786299 (ave = 0.72654594)
# Loss_G = 0.90943289 (ave = 4.68384714)
#
# Real Accuracy : 86.3529411764706
# Fake Accuracy : 3.5294117647058822
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [40/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.753s / 10iters, (0.475)	Data load 4.243s / 10iters, (0.424314)
# Loss_D = 0.59843558 (ave = 0.75117598)
# Loss_G = 4.41591787 (ave = 4.88955369)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [40/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.478s / 10iters, (0.048)	Data load 0.059s / 10iters, (0.005888)
# Loss_D = 0.30168334 (ave = 0.60773869)
# Loss_G = 4.85092735 (ave = 4.75132962)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [40/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.474s / 10iters, (0.047)	Data load 0.054s / 10iters, (0.005434)
# Loss_D = 0.39348447 (ave = 0.63567190)
# Loss_G = 3.45007014 (ave = 4.80381913)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [40/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.398s / 10iters, (0.040)	Data load 0.053s / 10iters, (0.005349)
# Loss_D = 0.62238753 (ave = 0.75850885)
# Loss_G = 5.59235668 (ave = 5.00898137)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [40/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.158s / 8iters, (0.020)	Data load 0.031s / 8iters, (0.003883)
# Loss_D = 1.15736496 (ave = 0.74666611)
# Loss_G = 5.22124672 (ave = 4.94205191)
#
# Real Accuracy : 84.23529411764706
# Fake Accuracy : 1.8823529411764706
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [41/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.557s / 10iters, (0.556)	Data load 5.025s / 10iters, (0.502502)
# Loss_D = 0.21585289 (ave = 1.04429689)
# Loss_G = 6.76659584 (ave = 5.26097047)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [41/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.470s / 10iters, (0.047)	Data load 0.058s / 10iters, (0.005777)
# Loss_D = 0.53534389 (ave = 0.81431235)
# Loss_G = 4.13728142 (ave = 4.89299659)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [41/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.512s / 10iters, (0.051)	Data load 0.061s / 10iters, (0.006088)
# Loss_D = 1.02312970 (ave = 0.83705231)
# Loss_G = 4.28761196 (ave = 4.77844888)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [41/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.393s / 10iters, (0.039)	Data load 0.056s / 10iters, (0.005647)
# Loss_D = 0.52927470 (ave = 0.76534922)
# Loss_G = 3.98670459 (ave = 4.72019906)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [41/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.153s / 8iters, (0.019)	Data load 0.031s / 8iters, (0.003815)
# Loss_D = 2.26234102 (ave = 0.88448558)
# Loss_G = 7.32802963 (ave = 4.95853971)
#
# Real Accuracy : 81.41176470588235
# Fake Accuracy : 5.411764705882353
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [42/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.367s / 10iters, (0.537)	Data load 4.768s / 10iters, (0.476764)
# Loss_D = 0.85991734 (ave = 0.89274616)
# Loss_G = 5.97473574 (ave = 4.94369712)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [42/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.515s / 10iters, (0.052)	Data load 0.129s / 10iters, (0.012883)
# Loss_D = 1.26116729 (ave = 0.70456799)
# Loss_G = 6.80450010 (ave = 4.63599824)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [42/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.602s / 10iters, (0.060)	Data load 0.063s / 10iters, (0.006339)
# Loss_D = 1.17231536 (ave = 0.69671195)
# Loss_G = 3.80226803 (ave = 4.67489405)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [42/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.380s / 10iters, (0.038)	Data load 0.055s / 10iters, (0.005513)
# Loss_D = 0.41413498 (ave = 0.62805625)
# Loss_G = 3.99973011 (ave = 4.61342907)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [42/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.156s / 8iters, (0.019)	Data load 0.031s / 8iters, (0.003908)
# Loss_D = 1.12373173 (ave = 0.65270122)
# Loss_G = 2.44142175 (ave = 4.54713048)
#
# Real Accuracy : 85.41176470588235
# Fake Accuracy : 4.470588235294118
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [43/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.751s / 10iters, (0.475)	Data load 4.030s / 10iters, (0.403028)
# Loss_D = 0.26055273 (ave = 0.77161217)
# Loss_G = 2.93098545 (ave = 4.72405565)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [43/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.463s / 10iters, (0.046)	Data load 0.062s / 10iters, (0.006159)
# Loss_D = 0.45206594 (ave = 0.68353123)
# Loss_G = 3.30641460 (ave = 4.86260711)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [43/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.481s / 10iters, (0.048)	Data load 0.047s / 10iters, (0.004749)
# Loss_D = 0.19772099 (ave = 0.61820391)
# Loss_G = 5.03639936 (ave = 4.54319318)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [43/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.459s / 10iters, (0.046)	Data load 0.056s / 10iters, (0.005617)
# Loss_D = 0.70966202 (ave = 0.58266166)
# Loss_G = 3.29764748 (ave = 4.61626034)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [43/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.174s / 8iters, (0.022)	Data load 0.033s / 8iters, (0.004135)
# Loss_D = 0.12905726 (ave = 0.60163660)
# Loss_G = 9.37227154 (ave = 4.78762698)
#
# Real Accuracy : 88.70588235294117
# Fake Accuracy : 3.0588235294117645
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [44/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.412s / 10iters, (0.541)	Data load 4.686s / 10iters, (0.468584)
# Loss_D = 0.45420602 (ave = 0.55883466)
# Loss_G = 2.98023319 (ave = 5.24872873)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [44/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.564s / 10iters, (0.056)	Data load 0.054s / 10iters, (0.005444)
# Loss_D = 0.48249629 (ave = 0.58570653)
# Loss_G = 5.80316305 (ave = 5.25093192)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [44/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.566s / 10iters, (0.057)	Data load 0.055s / 10iters, (0.005493)
# Loss_D = 0.32266134 (ave = 0.56712964)
# Loss_G = 2.51043510 (ave = 5.04864392)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [44/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.414s / 10iters, (0.041)	Data load 0.050s / 10iters, (0.005026)
# Loss_D = 0.76156157 (ave = 0.61631748)
# Loss_G = 4.02214527 (ave = 5.07412562)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [44/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.165s / 8iters, (0.021)	Data load 0.023s / 8iters, (0.002815)
# Loss_D = 0.02197342 (ave = 0.58760508)
# Loss_G = 7.07995272 (ave = 5.02324139)
#
# Real Accuracy : 85.41176470588235
# Fake Accuracy : 1.8823529411764706
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [45/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.443s / 10iters, (0.544)	Data load 4.715s / 10iters, (0.471474)
# Loss_D = 0.82811528 (ave = 0.63333290)
# Loss_G = 3.84742141 (ave = 4.76425302)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [45/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.575s / 10iters, (0.058)	Data load 0.071s / 10iters, (0.007119)
# Loss_D = 0.97212970 (ave = 0.70347087)
# Loss_G = 6.97923422 (ave = 5.07621210)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [45/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.550s / 10iters, (0.055)	Data load 0.081s / 10iters, (0.008079)
# Loss_D = 0.64540410 (ave = 0.61086689)
# Loss_G = 2.32999611 (ave = 4.98849533)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [45/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.331s / 10iters, (0.033)	Data load 0.057s / 10iters, (0.005732)
# Loss_D = 0.89422250 (ave = 0.59599852)
# Loss_G = 2.15125990 (ave = 4.83350047)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [45/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.157s / 8iters, (0.020)	Data load 0.027s / 8iters, (0.003408)
# Loss_D = 0.09117546 (ave = 0.59046848)
# Loss_G = 5.82383299 (ave = 4.81341972)
#
# Real Accuracy : 88.0
# Fake Accuracy : 4.0
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [46/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.688s / 10iters, (0.469)	Data load 4.110s / 10iters, (0.410968)
# Loss_D = 0.14667654 (ave = 0.35550753)
# Loss_G = 2.53933811 (ave = 4.40689025)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [46/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.520s / 10iters, (0.052)	Data load 0.041s / 10iters, (0.004093)
# Loss_D = 0.36780366 (ave = 0.60536762)
# Loss_G = 3.76987410 (ave = 4.72349962)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [46/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.604s / 10iters, (0.060)	Data load 0.104s / 10iters, (0.010425)
# Loss_D = 0.82415748 (ave = 0.63081470)
# Loss_G = 4.25417519 (ave = 4.58291358)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [46/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.455s / 10iters, (0.046)	Data load 0.074s / 10iters, (0.007395)
# Loss_D = 0.44898245 (ave = 0.69651556)
# Loss_G = 2.87803102 (ave = 4.70469306)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [46/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.161s / 8iters, (0.020)	Data load 0.031s / 8iters, (0.003874)
# Loss_D = 1.51909781 (ave = 0.67665703)
# Loss_G = 23.19564056 (ave = 5.09104654)
#
# Real Accuracy : 86.11764705882354
# Fake Accuracy : 3.764705882352941
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [47/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.389s / 10iters, (0.539)	Data load 4.886s / 10iters, (0.488610)
# Loss_D = 1.91077244 (ave = 2.31894180)
# Loss_G = 7.57584715 (ave = 4.76753993)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [47/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.620s / 10iters, (0.062)	Data load 0.081s / 10iters, (0.008143)
# Loss_D = 0.93719828 (ave = 1.58224431)
# Loss_G = 2.95903230 (ave = 4.81384566)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [47/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.487s / 10iters, (0.049)	Data load 0.036s / 10iters, (0.003598)
# Loss_D = 0.72309035 (ave = 1.54116292)
# Loss_G = 6.12019730 (ave = 4.93207575)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [47/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.423s / 10iters, (0.042)	Data load 0.053s / 10iters, (0.005277)
# Loss_D = 0.35562751 (ave = 1.30607760)
# Loss_G = 3.04872537 (ave = 4.61804019)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [47/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.185s / 8iters, (0.023)	Data load 0.036s / 8iters, (0.004495)
# Loss_D = 0.09235396 (ave = 1.23185792)
# Loss_G = 3.69213128 (ave = 4.57123318)
#
# Real Accuracy : 76.94117647058823
# Fake Accuracy : 6.117647058823529
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [48/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.511s / 10iters, (0.551)	Data load 4.795s / 10iters, (0.479529)
# Loss_D = 0.80274135 (ave = 0.88362673)
# Loss_G = 3.20995998 (ave = 4.93203051)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [48/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.525s / 10iters, (0.052)	Data load 0.055s / 10iters, (0.005540)
# Loss_D = 0.33647552 (ave = 0.57689820)
# Loss_G = 4.25399876 (ave = 4.64497577)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [48/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.548s / 10iters, (0.055)	Data load 0.058s / 10iters, (0.005833)
# Loss_D = 1.41954350 (ave = 0.65406214)
# Loss_G = 4.98302746 (ave = 4.36148403)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [48/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.449s / 10iters, (0.045)	Data load 0.059s / 10iters, (0.005874)
# Loss_D = 0.48090479 (ave = 0.61196944)
# Loss_G = 5.43266106 (ave = 4.38013600)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [48/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.183s / 8iters, (0.023)	Data load 0.025s / 8iters, (0.003096)
# Loss_D = 2.35633445 (ave = 0.69809580)
# Loss_G = 2.09738708 (ave = 4.40640045)
#
# Real Accuracy : 85.88235294117646
# Fake Accuracy : 3.764705882352941
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [49/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.712s / 10iters, (0.471)	Data load 4.191s / 10iters, (0.419089)
# Loss_D = 0.39997417 (ave = 1.08036572)
# Loss_G = 5.19692039 (ave = 5.17177888)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [49/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.530s / 10iters, (0.053)	Data load 0.057s / 10iters, (0.005698)
# Loss_D = 0.43543592 (ave = 0.82249170)
# Loss_G = 6.14167118 (ave = 5.08827117)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [49/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.547s / 10iters, (0.055)	Data load 0.058s / 10iters, (0.005819)
# Loss_D = 0.28500170 (ave = 0.79331812)
# Loss_G = 6.83470488 (ave = 4.81295657)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [49/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.458s / 10iters, (0.046)	Data load 0.050s / 10iters, (0.004997)
# Loss_D = 0.36713886 (ave = 0.74961225)
# Loss_G = 4.16310692 (ave = 4.76525058)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [49/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.177s / 8iters, (0.022)	Data load 0.029s / 8iters, (0.003587)
# Loss_D = 0.80317855 (ave = 0.71292649)
# Loss_G = 2.91966057 (ave = 4.65529397)
#
# Real Accuracy : 86.3529411764706
# Fake Accuracy : 4.235294117647059
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [50/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.531s / 10iters, (0.553)	Data load 5.043s / 10iters, (0.504349)
# Loss_D = 0.29360828 (ave = 0.80496490)
# Loss_G = 4.89763165 (ave = 5.01169412)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [50/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.554s / 10iters, (0.055)	Data load 0.058s / 10iters, (0.005808)
# Loss_D = 0.83040071 (ave = 0.69244958)
# Loss_G = 5.12825584 (ave = 4.69458193)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [50/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.594s / 10iters, (0.059)	Data load 0.054s / 10iters, (0.005391)
# Loss_D = 0.65794969 (ave = 0.59025753)
# Loss_G = 4.20909214 (ave = 4.53235194)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [50/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.380s / 10iters, (0.038)	Data load 0.047s / 10iters, (0.004713)
# Loss_D = 0.31829852 (ave = 0.59802588)
# Loss_G = 5.89341545 (ave = 4.38304835)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [50/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.171s / 8iters, (0.021)	Data load 0.035s / 8iters, (0.004386)
# Loss_D = 0.15369733 (ave = 0.59635519)
# Loss_G = 4.39530087 (ave = 4.44205584)
#
# Real Accuracy : 86.82352941176471
# Fake Accuracy : 3.5294117647058822
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [51/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.350s / 10iters, (0.535)	Data load 4.656s / 10iters, (0.465554)
# Loss_D = 0.68576998 (ave = 0.78612175)
# Loss_G = 6.21756697 (ave = 4.61794827)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [51/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.561s / 10iters, (0.056)	Data load 0.064s / 10iters, (0.006419)
# Loss_D = 0.91822535 (ave = 0.66418798)
# Loss_G = 3.16796637 (ave = 4.29810443)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [51/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.524s / 10iters, (0.052)	Data load 0.065s / 10iters, (0.006482)
# Loss_D = 0.46929353 (ave = 0.66142159)
# Loss_G = 4.08911705 (ave = 4.55900098)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [51/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.409s / 10iters, (0.041)	Data load 0.068s / 10iters, (0.006751)
# Loss_D = 0.64900380 (ave = 0.59674322)
# Loss_G = 5.12592173 (ave = 4.42382737)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [51/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.149s / 8iters, (0.019)	Data load 0.029s / 8iters, (0.003621)
# Loss_D = 0.45580971 (ave = 0.55629776)
# Loss_G = 7.58939505 (ave = 4.42188594)
#
# Real Accuracy : 87.29411764705883
# Fake Accuracy : 4.235294117647059
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [52/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.769s / 10iters, (0.477)	Data load 4.061s / 10iters, (0.406057)
# Loss_D = 0.85171402 (ave = 0.34776697)
# Loss_G = 5.67764521 (ave = 4.63639874)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [52/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.496s / 10iters, (0.050)	Data load 0.070s / 10iters, (0.006994)
# Loss_D = 0.62413990 (ave = 0.46370103)
# Loss_G = 4.72559977 (ave = 4.57050455)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [52/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.509s / 10iters, (0.051)	Data load 0.060s / 10iters, (0.006006)
# Loss_D = 0.02502489 (ave = 0.42081508)
# Loss_G = 4.86566353 (ave = 4.66894449)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [52/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.407s / 10iters, (0.041)	Data load 0.070s / 10iters, (0.006983)
# Loss_D = 0.25624493 (ave = 0.49943012)
# Loss_G = 5.87608099 (ave = 4.48669422)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [52/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.163s / 8iters, (0.020)	Data load 0.032s / 8iters, (0.003984)
# Loss_D = 1.73542464 (ave = 0.56929163)
# Loss_G = 14.79256630 (ave = 4.63325744)
#
# Real Accuracy : 88.70588235294117
# Fake Accuracy : 4.235294117647059
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [53/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.509s / 10iters, (0.551)	Data load 4.880s / 10iters, (0.488035)
# Loss_D = 1.44584119 (ave = 1.09387618)
# Loss_G = 6.62850142 (ave = 4.97601519)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [53/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.505s / 10iters, (0.050)	Data load 0.086s / 10iters, (0.008621)
# Loss_D = 0.90684617 (ave = 0.88595533)
# Loss_G = 6.32051611 (ave = 4.63813349)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [53/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.495s / 10iters, (0.050)	Data load 0.046s / 10iters, (0.004576)
# Loss_D = 0.46320194 (ave = 0.79945671)
# Loss_G = 3.54435635 (ave = 4.49088073)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [53/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.431s / 10iters, (0.043)	Data load 0.096s / 10iters, (0.009592)
# Loss_D = 0.86315131 (ave = 0.72193393)
# Loss_G = 6.69810867 (ave = 4.47917138)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [53/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.156s / 8iters, (0.019)	Data load 0.030s / 8iters, (0.003728)
# Loss_D = 0.10275074 (ave = 0.76078581)
# Loss_G = 6.04617023 (ave = 4.69012122)
#
# Real Accuracy : 82.82352941176471
# Fake Accuracy : 5.176470588235294
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [54/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.280s / 10iters, (0.528)	Data load 4.757s / 10iters, (0.475700)
# Loss_D = 0.35053477 (ave = 0.66479321)
# Loss_G = 3.18044567 (ave = 4.67723951)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [54/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.586s / 10iters, (0.059)	Data load 0.122s / 10iters, (0.012162)
# Loss_D = 1.73959386 (ave = 0.72526781)
# Loss_G = 5.97450018 (ave = 4.60625484)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [54/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.612s / 10iters, (0.061)	Data load 0.029s / 10iters, (0.002931)
# Loss_D = 0.18869735 (ave = 0.68279198)
# Loss_G = 7.76346064 (ave = 4.65511184)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [54/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.478s / 10iters, (0.048)	Data load 0.070s / 10iters, (0.006997)
# Loss_D = 0.13775104 (ave = 0.69576486)
# Loss_G = 2.70098495 (ave = 4.60908296)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [54/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.176s / 8iters, (0.022)	Data load 0.037s / 8iters, (0.004683)
# Loss_D = 0.75716114 (ave = 0.65850556)
# Loss_G = 1.05384886 (ave = 4.43549342)
#
# Real Accuracy : 85.88235294117646
# Fake Accuracy : 4.9411764705882355
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [55/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.705s / 10iters, (0.471)	Data load 4.049s / 10iters, (0.404923)
# Loss_D = 0.45966822 (ave = 0.80225398)
# Loss_G = 2.16848493 (ave = 5.17839062)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [55/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.512s / 10iters, (0.051)	Data load 0.049s / 10iters, (0.004892)
# Loss_D = 0.57864428 (ave = 0.72914963)
# Loss_G = 4.81840992 (ave = 4.77707105)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [55/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.486s / 10iters, (0.049)	Data load 0.040s / 10iters, (0.004013)
# Loss_D = 0.59906077 (ave = 0.68025058)
# Loss_G = 5.46870852 (ave = 4.73898015)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [55/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.398s / 10iters, (0.040)	Data load 0.061s / 10iters, (0.006106)
# Loss_D = 0.10800934 (ave = 0.63845624)
# Loss_G = 4.08590508 (ave = 4.63764461)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [55/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.173s / 8iters, (0.022)	Data load 0.027s / 8iters, (0.003386)
# Loss_D = 0.00965781 (ave = 0.61016277)
# Loss_G = 6.92724323 (ave = 4.64732010)
#
# Real Accuracy : 87.05882352941177
# Fake Accuracy : 4.705882352941177
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [56/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.523s / 10iters, (0.552)	Data load 4.914s / 10iters, (0.491395)
# Loss_D = 1.16668975 (ave = 0.56649958)
# Loss_G = 4.92580223 (ave = 4.46719432)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [56/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.521s / 10iters, (0.052)	Data load 0.063s / 10iters, (0.006289)
# Loss_D = 0.78155279 (ave = 0.64107894)
# Loss_G = 6.79594278 (ave = 4.45839731)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [56/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.553s / 10iters, (0.055)	Data load 0.084s / 10iters, (0.008396)
# Loss_D = 0.86645448 (ave = 0.60173584)
# Loss_G = 7.61075068 (ave = 4.32259405)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [56/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.457s / 10iters, (0.046)	Data load 0.058s / 10iters, (0.005813)
# Loss_D = 0.40844145 (ave = 0.67424218)
# Loss_G = 5.77518988 (ave = 4.33058069)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [56/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.176s / 8iters, (0.022)	Data load 0.033s / 8iters, (0.004084)
# Loss_D = 0.18401411 (ave = 0.67393373)
# Loss_G = 4.06129313 (ave = 4.31299648)
#
# Real Accuracy : 84.47058823529412
# Fake Accuracy : 4.705882352941177
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [57/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.681s / 10iters, (0.568)	Data load 5.079s / 10iters, (0.507879)
# Loss_D = 0.96273702 (ave = 0.52239470)
# Loss_G = 4.74963617 (ave = 4.42585492)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [57/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.507s / 10iters, (0.051)	Data load 0.047s / 10iters, (0.004669)
# Loss_D = 0.57210821 (ave = 0.54010422)
# Loss_G = 3.44653821 (ave = 4.45862942)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [57/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.455s / 10iters, (0.046)	Data load 0.070s / 10iters, (0.006974)
# Loss_D = 0.96482217 (ave = 0.50190609)
# Loss_G = 7.95986509 (ave = 4.44313776)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [57/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.446s / 10iters, (0.045)	Data load 0.058s / 10iters, (0.005791)
# Loss_D = 0.77367061 (ave = 0.55586934)
# Loss_G = 3.15026832 (ave = 4.53132147)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [57/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.165s / 8iters, (0.021)	Data load 0.022s / 8iters, (0.002800)
# Loss_D = 0.34334385 (ave = 0.54935846)
# Loss_G = 9.98583221 (ave = 4.63713252)
#
# Real Accuracy : 89.17647058823529
# Fake Accuracy : 4.0
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [58/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.810s / 10iters, (0.481)	Data load 4.355s / 10iters, (0.435549)
# Loss_D = 0.95791692 (ave = 0.67848828)
# Loss_G = 4.42182255 (ave = 4.49043980)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [58/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.507s / 10iters, (0.051)	Data load 0.070s / 10iters, (0.006984)
# Loss_D = 0.56700671 (ave = 0.61598973)
# Loss_G = 5.62862587 (ave = 4.75598094)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [58/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.510s / 10iters, (0.051)	Data load 0.062s / 10iters, (0.006226)
# Loss_D = 0.83806950 (ave = 0.68359150)
# Loss_G = 5.86104298 (ave = 4.68122024)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [58/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.475s / 10iters, (0.048)	Data load 0.068s / 10iters, (0.006845)
# Loss_D = 0.74813956 (ave = 0.64801862)
# Loss_G = 5.24434566 (ave = 4.56807899)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [58/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.167s / 8iters, (0.021)	Data load 0.033s / 8iters, (0.004066)
# Loss_D = 0.34078908 (ave = 0.68031695)
# Loss_G = 1.05256391 (ave = 4.52632290)
#
# Real Accuracy : 84.47058823529412
# Fake Accuracy : 4.705882352941177
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [59/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.380s / 10iters, (0.538)	Data load 4.844s / 10iters, (0.484407)
# Loss_D = 1.18412519 (ave = 0.94081622)
# Loss_G = 3.73185253 (ave = 5.36729314)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [59/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.553s / 10iters, (0.055)	Data load 0.060s / 10iters, (0.005952)
# Loss_D = 0.16319989 (ave = 0.69683810)
# Loss_G = 5.60136509 (ave = 4.81700926)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [59/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.550s / 10iters, (0.055)	Data load 0.049s / 10iters, (0.004923)
# Loss_D = 0.48084402 (ave = 0.60666941)
# Loss_G = 4.39977598 (ave = 4.51044912)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [59/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.474s / 10iters, (0.047)	Data load 0.062s / 10iters, (0.006218)
# Loss_D = 0.42121843 (ave = 0.59507630)
# Loss_G = 6.28456116 (ave = 4.55518793)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [59/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.182s / 8iters, (0.023)	Data load 0.032s / 8iters, (0.004058)
# Loss_D = 0.29905260 (ave = 0.57923747)
# Loss_G = 5.53830194 (ave = 4.54205646)
#
# Real Accuracy : 88.0
# Fake Accuracy : 4.705882352941177
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [60/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.488s / 10iters, (0.549)	Data load 4.883s / 10iters, (0.488341)
# Loss_D = 0.14302418 (ave = 0.24814465)
# Loss_G = 4.89803839 (ave = 4.48299387)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [60/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.530s / 10iters, (0.053)	Data load 0.063s / 10iters, (0.006300)
# Loss_D = 1.18340611 (ave = 0.35612168)
# Loss_G = 1.73326361 (ave = 4.31192580)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [60/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.565s / 10iters, (0.057)	Data load 0.071s / 10iters, (0.007149)
# Loss_D = 0.33909690 (ave = 0.54017535)
# Loss_G = 1.43135142 (ave = 4.62084571)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [60/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.379s / 10iters, (0.038)	Data load 0.046s / 10iters, (0.004597)
# Loss_D = 1.42074347 (ave = 0.57516133)
# Loss_G = 5.99097776 (ave = 4.70442492)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [60/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.174s / 8iters, (0.022)	Data load 0.030s / 8iters, (0.003786)
# Loss_D = 0.79774493 (ave = 0.55865121)
# Loss_G = 9.51976395 (ave = 4.76718126)
#
# Real Accuracy : 89.6470588235294
# Fake Accuracy : 4.235294117647059
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [61/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.690s / 10iters, (0.469)	Data load 4.087s / 10iters, (0.408688)
# Loss_D = 0.79601431 (ave = 0.88925831)
# Loss_G = 4.10985088 (ave = 4.50561512)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [61/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.466s / 10iters, (0.047)	Data load 0.054s / 10iters, (0.005385)
# Loss_D = 0.41296166 (ave = 0.74451851)
# Loss_G = 8.13331795 (ave = 4.81112846)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [61/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.486s / 10iters, (0.049)	Data load 0.069s / 10iters, (0.006935)
# Loss_D = 0.24413328 (ave = 0.72111699)
# Loss_G = 4.70361042 (ave = 4.71556776)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [61/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.440s / 10iters, (0.044)	Data load 0.065s / 10iters, (0.006547)
# Loss_D = 0.17243287 (ave = 0.66447882)
# Loss_G = 7.31753635 (ave = 4.67546846)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [61/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.167s / 8iters, (0.021)	Data load 0.026s / 8iters, (0.003303)
# Loss_D = 0.53735912 (ave = 0.67145106)
# Loss_G = 5.15495729 (ave = 4.51055243)
#
# Real Accuracy : 85.41176470588235
# Fake Accuracy : 5.882352941176471
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [62/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.357s / 10iters, (0.536)	Data load 4.730s / 10iters, (0.473000)
# Loss_D = 0.30229396 (ave = 0.42289205)
# Loss_G = 4.93794489 (ave = 5.30303111)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [62/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.481s / 10iters, (0.048)	Data load 0.057s / 10iters, (0.005684)
# Loss_D = 0.16246530 (ave = 0.46597324)
# Loss_G = 5.64551878 (ave = 4.80391136)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [62/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.711s / 10iters, (0.071)	Data load 0.091s / 10iters, (0.009054)
# Loss_D = 0.48167336 (ave = 0.47710348)
# Loss_G = 3.59696245 (ave = 4.55684616)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [62/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.389s / 10iters, (0.039)	Data load 0.062s / 10iters, (0.006231)
# Loss_D = 0.60750335 (ave = 0.52699803)
# Loss_G = 6.46561670 (ave = 4.61264706)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [62/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.164s / 8iters, (0.021)	Data load 0.032s / 8iters, (0.004014)
# Loss_D = 0.02039104 (ave = 0.52615468)
# Loss_G = 5.54053307 (ave = 4.61847823)
#
# Real Accuracy : 89.41176470588235
# Fake Accuracy : 3.5294117647058822
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [63/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.473s / 10iters, (0.547)	Data load 4.766s / 10iters, (0.476638)
# Loss_D = 0.45076180 (ave = 0.59270813)
# Loss_G = 7.27644873 (ave = 5.05317168)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [63/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.546s / 10iters, (0.055)	Data load 0.073s / 10iters, (0.007347)
# Loss_D = 0.54031277 (ave = 0.60360975)
# Loss_G = 4.53084183 (ave = 4.63275211)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [63/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.514s / 10iters, (0.051)	Data load 0.046s / 10iters, (0.004564)
# Loss_D = 0.25566417 (ave = 0.56542992)
# Loss_G = 3.39428496 (ave = 4.65009141)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [63/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.462s / 10iters, (0.046)	Data load 0.061s / 10iters, (0.006125)
# Loss_D = 0.23083168 (ave = 0.55989785)
# Loss_G = 6.09863186 (ave = 4.71010188)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [63/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.174s / 8iters, (0.022)	Data load 0.033s / 8iters, (0.004115)
# Loss_D = 0.04719757 (ave = 0.54285999)
# Loss_G = 5.61994267 (ave = 4.73786082)
#
# Real Accuracy : 87.05882352941177
# Fake Accuracy : 2.1176470588235294
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [64/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.711s / 10iters, (0.471)	Data load 4.195s / 10iters, (0.419529)
# Loss_D = 0.36231786 (ave = 0.42736586)
# Loss_G = 4.89461040 (ave = 4.68104405)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [64/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.591s / 10iters, (0.059)	Data load 0.065s / 10iters, (0.006483)
# Loss_D = 0.57883751 (ave = 0.40911059)
# Loss_G = 6.05384207 (ave = 4.81522024)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [64/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.639s / 10iters, (0.064)	Data load 0.074s / 10iters, (0.007379)
# Loss_D = 0.27662629 (ave = 0.36721752)
# Loss_G = 3.54056692 (ave = 4.66037677)
#
# ...
# Time 0.193s / 8iters, (0.024)	Data load 0.032s / 8iters, (0.004041)
# Loss_D = 0.03786581 (ave = 0.42678878)
# Loss_G = 6.78476572 (ave = 4.40892571)
#
# Real Accuracy : 91.29411764705883
# Fake Accuracy : 1.411764705882353
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [91/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.951s / 10iters, (0.495)	Data load 4.207s / 10iters, (0.420664)
# Loss_D = 0.40527248 (ave = 0.44774685)
# Loss_G = 5.86038780 (ave = 4.55844052)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [91/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.497s / 10iters, (0.050)	Data load 0.059s / 10iters, (0.005899)
# Loss_D = 0.22921212 (ave = 0.40407984)
# Loss_G = 4.92242479 (ave = 4.74349662)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [91/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.441s / 10iters, (0.044)	Data load 0.060s / 10iters, (0.005997)
# Loss_D = 0.29835948 (ave = 0.41044059)
# Loss_G = 5.88215446 (ave = 4.86928422)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [91/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.457s / 10iters, (0.046)	Data load 0.043s / 10iters, (0.004266)
# Loss_D = 0.57566094 (ave = 0.39391115)
# Loss_G = 3.80089402 (ave = 4.82213276)
#
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [91/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.164s / 8iters, (0.020)	Data load 0.032s / 8iters, (0.004040)
# Loss_D = 0.50947028 (ave = 0.37591508)
# Loss_G = 6.27345657 (ave = 4.74330880)
#
# Real Accuracy : 92.0
# Fake Accuracy : 2.588235294117647
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [92/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.606s / 10iters, (0.561)	Data load 4.749s / 10iters, (0.474938)
# Loss_D = 0.33952096 (ave = 0.55369610)
# Loss_G = 2.95375681 (ave = 5.42315149)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [92/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.573s / 10iters, (0.057)	Data load 0.077s / 10iters, (0.007670)
# Loss_D = 1.04056394 (ave = 0.51763049)
# Loss_G = 2.37176132 (ave = 5.19162364)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [92/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.409s / 10iters, (0.041)	Data load 0.057s / 10iters, (0.005725)
# Loss_D = 0.21646470 (ave = 0.46215425)
# Loss_G = 5.50224113 (ave = 5.10674634)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [92/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.390s / 10iters, (0.039)	Data load 0.045s / 10iters, (0.004504)
# Loss_D = 0.33360195 (ave = 0.41069609)
# Loss_G = 5.42409420 (ave = 4.99373369)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [92/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.181s / 8iters, (0.023)	Data load 0.028s / 8iters, (0.003485)
# Loss_D = 0.89854258 (ave = 0.40701505)
# Loss_G = 6.68007946 (ave = 4.89174108)
#
# Real Accuracy : 92.94117647058823
# Fake Accuracy : 1.8823529411764706
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [93/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.462s / 10iters, (0.546)	Data load 4.908s / 10iters, (0.490775)
# Loss_D = 0.17479299 (ave = 1.06841142)
# Loss_G = 5.60649490 (ave = 6.25479850)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [93/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.510s / 10iters, (0.051)	Data load 0.051s / 10iters, (0.005064)
# Loss_D = 0.48299047 (ave = 0.79142615)
# Loss_G = 8.73860264 (ave = 5.72840453)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [93/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.520s / 10iters, (0.052)	Data load 0.075s / 10iters, (0.007498)
# Loss_D = 0.80386114 (ave = 0.72082990)
# Loss_G = 4.81085968 (ave = 5.53003436)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [93/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.423s / 10iters, (0.042)	Data load 0.076s / 10iters, (0.007593)
# Loss_D = 0.26034746 (ave = 0.64080385)
# Loss_G = 2.82566214 (ave = 5.34559202)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [93/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.166s / 8iters, (0.021)	Data load 0.032s / 8iters, (0.003969)
# Loss_D = 0.05325918 (ave = 0.58834112)
# Loss_G = 2.39967847 (ave = 5.21321835)
#
# Real Accuracy : 89.6470588235294
# Fake Accuracy : 3.2941176470588234
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [94/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.798s / 10iters, (0.480)	Data load 4.198s / 10iters, (0.419779)
# Loss_D = 0.49625960 (ave = 0.49582551)
# Loss_G = 4.54291010 (ave = 5.24645228)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [94/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.528s / 10iters, (0.053)	Data load 0.084s / 10iters, (0.008426)
# Loss_D = 0.10745736 (ave = 0.52411570)
# Loss_G = 5.00252485 (ave = 5.27309774)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [94/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.544s / 10iters, (0.054)	Data load 0.059s / 10iters, (0.005939)
# Loss_D = 0.26722050 (ave = 0.46415943)
# Loss_G = 4.80023766 (ave = 4.97407091)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [94/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.462s / 10iters, (0.046)	Data load 0.060s / 10iters, (0.006009)
# Loss_D = 0.27430952 (ave = 0.42612301)
# Loss_G = 4.49105835 (ave = 4.72636588)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [94/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.164s / 8iters, (0.021)	Data load 0.034s / 8iters, (0.004247)
# Loss_D = 0.24172126 (ave = 0.46612968)
# Loss_G = 3.80815220 (ave = 4.76052624)
#
# Real Accuracy : 90.58823529411765
# Fake Accuracy : 5.411764705882353
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [95/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.503s / 10iters, (0.550)	Data load 4.995s / 10iters, (0.499516)
# Loss_D = 0.59796274 (ave = 0.75728860)
# Loss_G = 3.82211947 (ave = 5.09117399)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [95/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.580s / 10iters, (0.058)	Data load 0.048s / 10iters, (0.004778)
# Loss_D = 0.31542772 (ave = 0.56708072)
# Loss_G = 5.73083258 (ave = 4.85667492)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [95/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.382s / 10iters, (0.038)	Data load 0.066s / 10iters, (0.006617)
# Loss_D = 0.37218884 (ave = 0.51526643)
# Loss_G = 5.10101891 (ave = 4.82281783)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [95/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.502s / 10iters, (0.050)	Data load 0.062s / 10iters, (0.006189)
# Loss_D = 0.04157127 (ave = 0.45910794)
# Loss_G = 4.72279406 (ave = 4.92602049)
#
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [95/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.181s / 8iters, (0.023)	Data load 0.036s / 8iters, (0.004484)
# Loss_D = 0.51360214 (ave = 0.44988646)
# Loss_G = 6.18672705 (ave = 4.82413427)
#
# Real Accuracy : 92.47058823529412
# Fake Accuracy : 4.470588235294118
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [96/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.409s / 10iters, (0.541)	Data load 4.935s / 10iters, (0.493530)
# Loss_D = 0.45525688 (ave = 0.43317752)
# Loss_G = 4.18568182 (ave = 5.07399158)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [96/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.552s / 10iters, (0.055)	Data load 0.072s / 10iters, (0.007205)
# Loss_D = 0.06161173 (ave = 0.39576032)
# Loss_G = 5.29931021 (ave = 4.70560384)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [96/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.542s / 10iters, (0.054)	Data load 0.086s / 10iters, (0.008571)
# Loss_D = 1.31068134 (ave = 0.42776731)
# Loss_G = 7.14415407 (ave = 4.70202275)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [96/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.367s / 10iters, (0.037)	Data load 0.048s / 10iters, (0.004823)
# Loss_D = 0.47700769 (ave = 0.41875519)
# Loss_G = 5.56849861 (ave = 4.67197907)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [96/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.162s / 8iters, (0.020)	Data load 0.033s / 8iters, (0.004132)
# Loss_D = 0.77976316 (ave = 0.41077232)
# Loss_G = 0.65274966 (ave = 4.56098526)
#
# Real Accuracy : 91.76470588235294
# Fake Accuracy : 3.5294117647058822
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [97/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.793s / 10iters, (0.479)	Data load 4.290s / 10iters, (0.428997)
# Loss_D = 0.58673167 (ave = 0.35428734)
# Loss_G = 5.91046333 (ave = 4.79505105)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [97/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.530s / 10iters, (0.053)	Data load 0.049s / 10iters, (0.004948)
# Loss_D = 0.59871936 (ave = 0.38173377)
# Loss_G = 10.56219387 (ave = 4.99854642)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [97/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.555s / 10iters, (0.056)	Data load 0.072s / 10iters, (0.007240)
# Loss_D = 0.23991901 (ave = 0.48581564)
# Loss_G = 3.34624243 (ave = 4.83952226)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# epoch: [97/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.394s / 10iters, (0.039)	Data load 0.055s / 10iters, (0.005490)
# Loss_D = 0.45547882 (ave = 0.46578254)
# Loss_G = 5.36166573 (ave = 4.82257140)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [97/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.157s / 8iters, (0.020)	Data load 0.031s / 8iters, (0.003852)
# Loss_D = 1.37699795 (ave = 0.48985148)
# Loss_G = 1.70109642 (ave = 4.74582190)
#
# Real Accuracy : 89.6470588235294
# Fake Accuracy : 2.588235294117647
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [98/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.538s / 10iters, (0.554)	Data load 4.983s / 10iters, (0.498297)
# Loss_D = 0.71674085 (ave = 0.63953131)
# Loss_G = 4.08542824 (ave = 5.52359724)
#
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [98/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.477s / 10iters, (0.048)	Data load 0.046s / 10iters, (0.004616)
# Loss_D = 0.07425234 (ave = 0.56889171)
# Loss_G = 3.34064579 (ave = 5.17381623)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [98/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.491s / 10iters, (0.049)	Data load 0.071s / 10iters, (0.007054)
# Loss_D = 0.30328301 (ave = 0.51688244)
# Loss_G = 6.19684696 (ave = 5.06153866)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [98/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.418s / 10iters, (0.042)	Data load 0.052s / 10iters, (0.005168)
# Loss_D = 0.34092063 (ave = 0.44761887)
# Loss_G = 4.64433193 (ave = 4.85099361)
#
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [98/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.151s / 8iters, (0.019)	Data load 0.029s / 8iters, (0.003566)
# Loss_D = 0.00645366 (ave = 0.42654397)
# Loss_G = 8.68207645 (ave = 4.84007657)
#
# Real Accuracy : 91.05882352941177
# Fake Accuracy : 3.2941176470588234
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [99/100] iteration: [10/48]	Learning rate: 0.0002
# Time 5.369s / 10iters, (0.537)	Data load 4.830s / 10iters, (0.483040)
# Loss_D = 0.34711495 (ave = 0.34332691)
# Loss_G = 3.59065032 (ave = 4.73282008)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# epoch: [99/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.478s / 10iters, (0.048)	Data load 0.059s / 10iters, (0.005929)
# Loss_D = 2.41776037 (ave = 0.57988222)
# Loss_G = 2.29596162 (ave = 5.07541698)
#
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# epoch: [99/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.563s / 10iters, (0.056)	Data load 0.082s / 10iters, (0.008216)
# Loss_D = 0.75693488 (ave = 0.65836067)
# Loss_G = 4.73931026 (ave = 5.05780741)
#
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# epoch: [99/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.537s / 10iters, (0.054)	Data load 0.078s / 10iters, (0.007827)
# Loss_D = 0.13883600 (ave = 0.61040942)
# Loss_G = 5.39275551 (ave = 5.06134470)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# epoch: [99/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.185s / 8iters, (0.023)	Data load 0.036s / 8iters, (0.004531)
# Loss_D = 0.01311568 (ave = 0.60902081)
# Loss_G = 6.52740288 (ave = 5.20713668)
#
# Real Accuracy : 87.29411764705883
# Fake Accuracy : 3.5294117647058822
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [100/100] iteration: [10/48]	Learning rate: 0.0002
# Time 4.878s / 10iters, (0.488)	Data load 4.414s / 10iters, (0.441435)
# Loss_D = 0.77063191 (ave = 0.62388550)
# Loss_G = 5.23024750 (ave = 5.20912609)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# epoch: [100/100] iteration: [20/48]	Learning rate: 0.0002
# Time 0.469s / 10iters, (0.047)	Data load 0.074s / 10iters, (0.007353)
# Loss_D = 0.30213892 (ave = 0.55489609)
# Loss_G = 5.22424507 (ave = 5.27667892)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [100/100] iteration: [30/48]	Learning rate: 0.0002
# Time 0.586s / 10iters, (0.059)	Data load 0.039s / 10iters, (0.003927)
# Loss_D = 0.60972428 (ave = 0.57522278)
# Loss_G = 3.95551729 (ave = 5.29566000)
#
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# epoch: [100/100] iteration: [40/48]	Learning rate: 0.0002
# Time 0.364s / 10iters, (0.036)	Data load 0.022s / 10iters, (0.002218)
# Loss_D = 0.13532245 (ave = 0.59369436)
# Loss_G = 4.40797377 (ave = 5.16384199)
#
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# epoch: [100/100] iteration: [48/48]	Learning rate: 0.0002
# Time 0.163s / 8iters, (0.020)	Data load 0.026s / 8iters, (0.003241)
# Loss_D = 0.05316137 (ave = 0.55026492)
# Loss_G = 7.22788715 (ave = 5.13222945)
#
# Real Accuracy : 88.0
# Fake Accuracy : 3.2941176470588234

# %%
#load the saved models here
def generate_images(batch_size):
  #fake_num = math.ceil(batch_size/class_num)
  conditional_z, z_label = conditional_latent_generator(distribution, 2, batch_size)

  noise = conditional_z.view(-1, z_dim, 1, 1)
  print(noise.shape)
  if use_cuda:
    noise = noise.cuda(gpu)

  fake = G(noise)
  print(fake.shape)

  for i, label in enumerate(z_label):
    cv = output_images_dir+"/covid"
    ncv=output_images_dir+"/noncovid"

    os.makedirs(cv, exist_ok = True)
    os.makedirs(ncv, exist_ok = True)

    if label == 0:
      vutils.save_image(fake[i].detach(), ncv+'/fake_samples_{:03d}.png'.format(i),normalize=True, nrow=5)
    else:
      vutils.save_image(fake[i].detach(), cv+'/fake_samples_{:03d}.png'.format(i),normalize=True, nrow=5)


generate_images(2000)
# Out:
# torch.Size([2000, 100, 1, 1])
# torch.Size([2000, 3, 64, 64])

# %%
# G = torch.load(checkpoint_dir+"/gan/G_epoch_19.pth")
# generate_images(50)
# Out:
# torch.Size([32, 100, 1, 1])
# torch.Size([32, 3, 64, 64])
