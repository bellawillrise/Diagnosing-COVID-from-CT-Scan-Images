# %% [markdown]
# <a href="https://colab.research.google.com/github/abbyambita/Diagnosing-COVID-from-CT-Scan-Images/blob/main/ViT_H_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/My Drive/CS 284 Mini-Project/Code"
# Out:
# /content/gdrive/.shortcut-targets-by-id/1eVFVz23F6ROX0s10Oe3tT9HVzr502iW2/CS 284 Mini-Project/Code

# %%
# !pip install ml-collections
# Out:
# ...
#      |████████████████████████████████| 92kB 4.7MB/s
# ...

# %%
# %cd apex
# !python setup.py install
# Out:
# /content/gdrive/.shortcut-targets-by-id/1eVFVz23F6ROX0s10Oe3tT9HVzr502iW2/CS 284 Mini-Project/Code/apex
#
#
# torch.__version__  = 1.7.0+cu101
#
#
# setup.py:67: UserWarning: Option --pyprof not specified. Not installing PyProf dependencies!
#   warnings.warn("Option --pyprof not specified. Not installing PyProf dependencies!")
# running install
# running bdist_egg
# running egg_info
# writing apex.egg-info/PKG-INFO
# writing dependency_links to apex.egg-info/dependency_links.txt
# writing top-level names to apex.egg-info/top_level.txt
# writing manifest file 'apex.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/apex
# copying build/lib/apex/__init__.py -> build/bdist.linux-x86_64/egg/apex
# creating build/bdist.linux-x86_64/egg/apex/reparameterization
# ...

# %%
# %cd ../
# Out:
# /content/gdrive/.shortcut-targets-by-id/1eVFVz23F6ROX0s10Oe3tT9HVzr502iW2/CS 284 Mini-Project/Code

# %% [markdown]
# ## ViT-H_14

# %% [markdown]
# ### COVID-CT

# %%
# !python ViT-pytorch/train.py --name git_h14 --dataset git --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 8 --eval_batch_size 8 --num_steps 10000 --output_dir ViT-pytorch/saved_models
# Out:
# Streaming output truncated to the last 5000 lines.
# 01/18/2021 10:27:41 - INFO - __main__ - Valid Accuracy: 0.82266
# Training (2214 / 10000 Steps) (loss=0.00007): 100% 54/54 [00:55<00:00,  1.04s/it]
# Training (2268 / 10000 Steps) (loss=0.00001): 100% 54/54 [00:48<00:00,  1.11it/s]
# Training (2300 / 10000 Steps) (loss=0.00097):  57% 31/54 [00:28<00:20,  1.12it/s]01/18/2021 10:29:11 - INFO - __main__ - ***** Running Validation *****
# 01/18/2021 10:29:11 - INFO - __main__ -   Num steps = 26
# 01/18/2021 10:29:11 - INFO - __main__ -   Batch size = 8
#
# Validating... (loss=X.X):   0% 0/26 [00:00<?, ?it/s]
# Validating... (loss=3.31181):   0% 0/26 [00:00<?, ?it/s]
# Validating... (loss=3.31181):   4% 1/26 [00:00<00:19,  1.26it/s]
# Validating... (loss=1.49501):   4% 1/26 [00:01<00:19,  1.26it/s]
# Validating... (loss=1.49501):   8% 2/26 [00:01<00:15,  1.58it/s]
# Validating... (loss=0.00024):   8% 2/26 [00:01<00:15,  1.58it/s]
# ...

# %%
# !python ViT-pytorch/test.py --name git_h14 --dataset git --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 8 --eval_batch_size 8 --num_steps 10000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/train.py --name git_with_acgan_h14 --dataset git_with_acgan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32  --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/test.py --name git_with_acgan_h14 --dataset git_with_acgan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32  --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/train.py --name git_with_bagan_h14 --dataset git_with_bagan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32  --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/test.py --name git_with_bagan_h14 --dataset git_with_bagan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32  --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/train.py --name git_with_sagan_h14 --dataset git_with_sagan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 8 --eval_batch_size 8  --num_steps 10000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/18/2021 13:38:08 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/18/2021 13:39:09 - INFO - __main__ - classifier: token
# hidden_size: 1280
# patches:
#   size: !!python/tuple [14, 14]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 5120, num_heads: 16,
#   num_layers: 32}
#
# 01/18/2021 13:39:09 - INFO - __main__ - Training parameters Namespace(dataset='git_with_sagan', decay_type='cosine', device=device(type='cuda'), eval_batch_size=8, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-H_14', n_gpu=1, name='git_with_sagan_h14', num_steps=10000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-H_14.npz', seed=42, train_batch_size=8, warmup_steps=500, weight_decay=0)
# ...

# %%
# !python ViT-pytorch/test.py --name git_with_sagan_h14 --dataset git_with_sagan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 8 --eval_batch_size 8  --num_steps 10000 --output_dir ViT-pytorch/saved_models

# %% [markdown]
# ### Sars-CoV-2

# %%
# !python ViT-pytorch/train.py --name kaggle_h14 --dataset kaggle --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32  --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/test.py --name kaggle_h14 --dataset kaggle --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32  --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/train.py --name kaggle_with_acgan_h14 --dataset kaggle_with_acgan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/test.py --name kaggle_with_acgan_h14 --dataset kaggle_with_acgan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/train.py --name kaggle_with_bagan_h14 --dataset kaggle_with_bagan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/test.py --name kaggle_with_bagan_h14 --dataset kaggle_with_bagan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/train.py --name kaggle_with_sagan_h14 --dataset kaggle_with_sagan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/test.py --name kaggle_with_sagan_h14 --dataset kaggle_with_sagan --model_type ViT-H_14 --pretrained_dir ViT-pytorch/checkpoint/ViT-H_14.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models
