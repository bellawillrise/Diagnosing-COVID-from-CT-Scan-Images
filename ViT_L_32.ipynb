# %% [markdown]
# <a href="https://colab.research.google.com/github/abbyambita/Diagnosing-COVID-from-CT-Scan-Images/blob/main/ViT_L_32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd "/content/gdrive/My Drive/CS 284 Mini-Project/Code"
# Out:
# /content/gdrive/.shortcut-targets-by-id/1eVFVz23F6ROX0s10Oe3tT9HVzr502iW2/CS 284 Mini-Project/Code

# %%
# !pip install ml-collections

# %%
# %cd apex
# !python setup.py install
# Out:
# /content/gdrive/.shortcut-targets-by-id/1eVFVz23F6ROX0s10Oe3tT9HVzr502iW2/CS 284 Mini-Project/Code/apex
#
#
# torch.__version__  = 1.7.0+cu101
#
#
# setup.py:67: UserWarning: Option --pyprof not specified. Not installing PyProf dependencies!
#   warnings.warn("Option --pyprof not specified. Not installing PyProf dependencies!")
# running install
# running bdist_egg
# running egg_info
# writing apex.egg-info/PKG-INFO
# writing dependency_links to apex.egg-info/dependency_links.txt
# writing top-level names to apex.egg-info/top_level.txt
# writing manifest file 'apex.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/apex
# copying build/lib/apex/__init__.py -> build/bdist.linux-x86_64/egg/apex
# creating build/bdist.linux-x86_64/egg/apex/reparameterization
# ...

# %%
# %cd ../
# Out:
# /content/gdrive/.shortcut-targets-by-id/1eVFVz23F6ROX0s10Oe3tT9HVzr502iW2/CS 284 Mini-Project/Code

# %% [markdown]
# ## ViT-L_32

# %% [markdown]
# ### COVID-CT

# %%
# !python ViT-pytorch/train.py --name git_l32 --dataset git --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/18/2021 06:29:37 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/18/2021 06:30:12 - INFO - __main__ - classifier: token
# hidden_size: 1024
# patches:
#   size: !!python/tuple [32, 32]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 4096, num_heads: 16,
#   num_layers: 24}
#
# 01/18/2021 06:30:12 - INFO - __main__ - Training parameters Namespace(dataset='git', decay_type='cosine', device=device(type='cuda'), eval_batch_size=32, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-L_32', n_gpu=1, name='git_l32', num_steps=5000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-L_32.npz', seed=42, train_batch_size=32, warmup_steps=500, weight_decay=0)
# ...

# %%
# !python ViT-pytorch/test.py --name git_l32 --dataset git --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/18/2021 07:14:50 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/18/2021 07:15:32 - INFO - __main__ - classifier: token
# hidden_size: 1024
# patches:
#   size: !!python/tuple [32, 32]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 4096, num_heads: 16,
#   num_layers: 24}
#
# 01/18/2021 07:15:32 - INFO - __main__ - Training parameters Namespace(dataset='git', decay_type='cosine', device=device(type='cuda'), eval_batch_size=32, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-L_32', n_gpu=1, name='git_l32', num_steps=5000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-L_32.npz', seed=42, train_batch_size=32, warmup_steps=500, weight_decay=0)
# ...

# %%
# !python ViT-pytorch/train.py --name git_with_acgan_l32 --dataset git_with_acgan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/18/2021 07:17:53 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/18/2021 07:18:12 - INFO - __main__ - classifier: token
# hidden_size: 1024
# patches:
#   size: !!python/tuple [32, 32]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 4096, num_heads: 16,
#   num_layers: 24}
#
# 01/18/2021 07:18:12 - INFO - __main__ - Training parameters Namespace(dataset='git_with_acgan', decay_type='cosine', device=device(type='cuda'), eval_batch_size=32, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-L_32', n_gpu=1, name='git_with_acgan_l32', num_steps=5000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-L_32.npz', seed=42, train_batch_size=32, warmup_steps=500, weight_decay=0)
# ...

# %%
# !python ViT-pytorch/test.py --name git_with_acgan_l32 --dataset git_with_acgan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/18/2021 07:57:16 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/18/2021 07:57:29 - INFO - __main__ - classifier: token
# hidden_size: 1024
# patches:
#   size: !!python/tuple [32, 32]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 4096, num_heads: 16,
#   num_layers: 24}
#
# 01/18/2021 07:57:29 - INFO - __main__ - Training parameters Namespace(dataset='git_with_acgan', decay_type='cosine', device=device(type='cuda'), eval_batch_size=32, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-L_32', n_gpu=1, name='git_with_acgan_l32', num_steps=5000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-L_32.npz', seed=42, train_batch_size=32, warmup_steps=500, weight_decay=0)
# ...

# %%
# !python ViT-pytorch/train.py --name git_with_bagan_l32 --dataset git_with_bagan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/18/2021 07:59:47 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/18/2021 08:00:00 - INFO - __main__ - classifier: token
# hidden_size: 1024
# patches:
#   size: !!python/tuple [32, 32]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 4096, num_heads: 16,
#   num_layers: 24}
#
# 01/18/2021 08:00:00 - INFO - __main__ - Training parameters Namespace(dataset='git_with_bagan', decay_type='cosine', device=device(type='cuda'), eval_batch_size=32, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-L_32', n_gpu=1, name='git_with_bagan_l32', num_steps=5000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-L_32.npz', seed=42, train_batch_size=32, warmup_steps=500, weight_decay=0)
# ...

# %%
# !python ViT-pytorch/test.py --name git_with_bagan_l32 --dataset git_with_bagan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/18/2021 08:37:14 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/18/2021 08:37:56 - INFO - __main__ - classifier: token
# hidden_size: 1024
# patches:
#   size: !!python/tuple [32, 32]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 4096, num_heads: 16,
#   num_layers: 24}
#
# 01/18/2021 08:37:56 - INFO - __main__ - Training parameters Namespace(dataset='git_with_bagan', decay_type='cosine', device=device(type='cuda'), eval_batch_size=32, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-L_32', n_gpu=1, name='git_with_bagan_l32', num_steps=5000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-L_32.npz', seed=42, train_batch_size=32, warmup_steps=500, weight_decay=0)
# ...

# %%
# !python ViT-pytorch/train.py --name git_with_sagan_l32 --dataset git_with_sagan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/18/2021 08:40:18 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/18/2021 08:40:45 - INFO - __main__ - classifier: token
# hidden_size: 1024
# patches:
#   size: !!python/tuple [32, 32]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 4096, num_heads: 16,
#   num_layers: 24}
#
# 01/18/2021 08:40:45 - INFO - __main__ - Training parameters Namespace(dataset='git_with_sagan', decay_type='cosine', device=device(type='cuda'), eval_batch_size=32, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-L_32', n_gpu=1, name='git_with_sagan_l32', num_steps=5000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-L_32.npz', seed=42, train_batch_size=32, warmup_steps=500, weight_decay=0)
# ...

# %%
# !python ViT-pytorch/test.py --name git_with_sagan_l32 --dataset git_with_sagan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 5000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/18/2021 09:19:19 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/18/2021 09:20:01 - INFO - __main__ - classifier: token
# hidden_size: 1024
# patches:
#   size: !!python/tuple [32, 32]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 4096, num_heads: 16,
#   num_layers: 24}
#
# 01/18/2021 09:20:01 - INFO - __main__ - Training parameters Namespace(dataset='git_with_sagan', decay_type='cosine', device=device(type='cuda'), eval_batch_size=32, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-L_32', n_gpu=1, name='git_with_sagan_l32', num_steps=5000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-L_32.npz', seed=42, train_batch_size=32, warmup_steps=500, weight_decay=0)
# ...

# %% [markdown]
# ### Sars-CoV-2

# %%
# !python ViT-pytorch/train.py --name kaggle_l32 --dataset kaggle --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 10000 --output_dir ViT-pytorch/saved_models
# Out:
# Streaming output truncated to the last 5000 lines.
# 01/19/2021 01:08:16 - INFO - __main__ -
#
# 01/19/2021 01:08:16 - INFO - __main__ - Validation Results
# 01/19/2021 01:08:16 - INFO - __main__ - Global Steps: 900
# 01/19/2021 01:08:16 - INFO - __main__ - Valid Loss: 0.33223
# 01/19/2021 01:08:16 - INFO - __main__ - Valid Accuracy: 0.85096
# Training (950 / 10000 Steps) (loss=0.08850): 100% 95/95 [00:43<00:00,  2.19it/s]
# Training (1000 / 10000 Steps) (loss=0.11499):  52% 49/95 [00:20<00:17,  2.57it/s]01/19/2021 01:08:56 - INFO - __main__ - ***** Running Validation *****
# 01/19/2021 01:08:56 - INFO - __main__ -   Num steps = 25
# 01/19/2021 01:08:56 - INFO - __main__ -   Batch size = 32
#
# Validating... (loss=X.X):   0% 0/25 [00:00<?, ?it/s]
# Validating... (loss=0.00703):   0% 0/25 [00:00<?, ?it/s]
# Validating... (loss=0.00703):   4% 1/25 [00:00<00:22,  1.07it/s]
# Validating... (loss=0.10406):   4% 1/25 [00:01<00:22,  1.07it/s]
# ...

# %%
# !python ViT-pytorch/test.py --name kaggle_l32 --dataset kaggle --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 10000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/19/2021 02:16:58 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/19/2021 02:17:40 - INFO - __main__ - classifier: token
# hidden_size: 1024
# patches:
#   size: !!python/tuple [32, 32]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 4096, num_heads: 16,
#   num_layers: 24}
#
# 01/19/2021 02:17:40 - INFO - __main__ - Training parameters Namespace(dataset='kaggle', decay_type='cosine', device=device(type='cuda'), eval_batch_size=32, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-L_32', n_gpu=1, name='kaggle_l32', num_steps=5000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-L_32.npz', seed=42, train_batch_size=32, warmup_steps=500, weight_decay=0)
# ...

# %%
# !python ViT-pytorch/train.py --name kaggle_with_acgan_l32 --dataset kaggle_with_acgan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 10000 --output_dir ViT-pytorch/saved_models
# Out:
# Streaming output truncated to the last 5000 lines.
# Validating... (loss=0.09560):   4% 1/25 [00:01<00:25,  1.05s/it]
# Validating... (loss=0.08855):   4% 1/25 [00:01<00:25,  1.05s/it]
# Validating... (loss=0.08855):  12% 3/25 [00:01<00:16,  1.31it/s]
# Validating... (loss=0.00655):  12% 3/25 [00:01<00:16,  1.31it/s]
# Validating... (loss=0.00655):  16% 4/25 [00:01<00:11,  1.76it/s]
# Validating... (loss=0.01621):  16% 4/25 [00:01<00:11,  1.76it/s]
# Validating... (loss=0.01621):  20% 5/25 [00:01<00:09,  2.13it/s]
# Validating... (loss=0.61485):  20% 5/25 [00:01<00:09,  2.13it/s]
# Validating... (loss=0.59218):  20% 5/25 [00:01<00:09,  2.13it/s]
# Validating... (loss=0.59218):  28% 7/25 [00:01<00:06,  2.80it/s]
# Validating... (loss=0.18593):  28% 7/25 [00:01<00:06,  2.80it/s]
# Validating... (loss=0.23145):  28% 7/25 [00:02<00:06,  2.80it/s]
# Validating... (loss=0.23145):  36% 9/25 [00:02<00:04,  3.21it/s]
# Validating... (loss=0.05700):  36% 9/25 [00:02<00:04,  3.21it/s]
# ...

# %%
# !python ViT-pytorch/test.py --name kaggle_with_acgan_l32 --dataset kaggle_with_acgan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 10000 --output_dir ViT-pytorch/saved_models
# Out:
# 01/19/2021 03:46:53 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 01/19/2021 03:47:35 - INFO - __main__ - classifier: token
# hidden_size: 1024
# patches:
#   size: !!python/tuple [32, 32]
# representation_size: null
# transformer: {attention_dropout_rate: 0.0, dropout_rate: 0.1, mlp_dim: 4096, num_heads: 16,
#   num_layers: 24}
#
# 01/19/2021 03:47:35 - INFO - __main__ - Training parameters Namespace(dataset='kaggle_with_acgan', decay_type='cosine', device=device(type='cuda'), eval_batch_size=32, eval_every=100, fp16=True, fp16_opt_level='O2', gradient_accumulation_steps=1, img_size=224, learning_rate=0.03, local_rank=-1, loss_scale=0, max_grad_norm=1.0, model_type='ViT-L_32', n_gpu=1, name='kaggle_with_acgan_l32', num_steps=10000, output_dir='ViT-pytorch/saved_models', pretrained_dir='ViT-pytorch/checkpoint/ViT-L_32.npz', seed=42, train_batch_size=32, warmup_steps=500, weight_decay=0)
# ...

# %%
# !python ViT-pytorch/train.py --name kaggle_with_bagan_l32 --dataset kaggle_with_bagan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 10000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/test.py --name kaggle_with_bagan_l32 --dataset kaggle_with_bagan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 10000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/train.py --name kaggle_with_sagan_l32 --dataset kaggle_with_sagan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 10000 --output_dir ViT-pytorch/saved_models

# %%
# !python ViT-pytorch/test.py --name kaggle_with_sagan_l32 --dataset kaggle_with_sagan --model_type ViT-L_32 --pretrained_dir ViT-pytorch/checkpoint/ViT-L_32.npz --fp16 --fp16_opt_level O2 --train_batch_size 32 --eval_batch_size 32 --num_steps 10000 --output_dir ViT-pytorch/saved_models
